# %%
import numpy as np
np.set_printoptions(suppress=True,precision=7)

# %% [markdown]
# # Лабораторна робота №1

# %% [markdown]
# ## Цільова функція:

# %% [markdown]
# $$11x^2 + 14y^2 + z^2 + 0,01xy - 0,001yz - y$$

# %%
target_function = lambda x: 11*x[0]**2 + 14*x[1]**2 + x[2]**2 + 0.01*x[0]*x[1] - 0.001*x[1]*x[2] - x[1]

# %% [markdown]
# ## Умови зупинки:

# %% [markdown]
# $$||x^{k+1} - x^k||\leq\epsilon$$

# %%
def x_norm_stop(x_prev,x_cur,epselon):
    return np.linalg.norm(x_prev-x_cur) < epselon

# %% [markdown]
# $$||f(x^{k+1}) - f(x^k)||\leq\epsilon$$

# %%
def func_abs_stop(func_prev,func_cur,epselon):
    return abs(func_prev - func_cur) < epselon

# %% [markdown]
# $$||f'(x^{k+1})||\leq\epsilon$$

# %%
def grad_abs_stop(grad,epselon):
    return np.linalg.norm(grad)<epselon

# %% [markdown]
# ## Градієнтний спуск

# %%
class GradientDescent:
    
    def __init__(self, target_func, initial_x, step_size, grad_step_size, adaptive_beta=0):
        self.f = target_func
        self.x = initial_x
        
        self.f_value = self.f(self.x)
        
        self.grad_step_size = grad_step_size
        self.step_size = step_size
        self.adaptive_beta = adaptive_beta
        self.adaptive_alpha = step_size
        
        self.grad = None
        
    @staticmethod
    def partial_deriv(f, x, h, var_num):
        x_back, x_forward = x.copy(), x.copy()
        
        # Increase x_back in such a way: (x-h;y)
        x_back[var_num] = x_back[var_num] - h 
        # Increase x_forward in such a way: (x+h;y)
        x_forward[var_num] = x_forward[var_num] + h
        
        return (f(x_forward) - f(x_back))/(2*h)
    
    @staticmethod
    def compose_grad_vec(f, x, h):
        # Compose vector from partial derivatives
        return np.array([GradientDescent.partial_deriv(f,x,h,i) for i in range(x.shape[0])])
        
    def backward(self):
        self.grad = GradientDescent.compose_grad_vec(self.f, self.x, self.grad_step_size) 
        
    def zero_grad(self):
        self.grad = np.zeros(self.x.shape[0])
        
    def step(self):
        
        # if beta > 0 we are using adaptive step_size
        if self.adaptive_beta == 0:
            # x_k+1 = x_k - alpha_k * f(x_k)'
            self.x = self.x - self.step_size * self.grad
            self.f_value = self.f(self.x)
        else:
            self.step_size = self.adaptive_alpha
            
            # decrease alpha_k until f(x_k) > f(x_k - x_k - alpha_k * f(x_k)')
            while self.f(self.x) < self.f(self.x - self.step_size * self.grad):
                # alpha_k = alpha_k * beta
                self.step_size = self.step_size * self.adaptive_beta
            
            # x_k+1 = x_k - alpha_k * f(x_k)'
            self.x = self.x - self.step_size * self.grad
            self.f_value = self.f(self.x)
                
                
    def info(self):
        print('Current x: {}'.format(self.x))
        print('Current f(x): {}'.format(self.f_value))
        print('Current grad: {}'.format(self.grad))
        print('Step size: {}'.format(self.step_size))
        print('Gradient step size: {}'.format(self.grad_step_size))

# %% [markdown]
# Застосуємо метод з постійною величиною кроку

# %%
grad_descent = GradientDescent(target_func=target_function,
                               initial_x=np.array([10.,10.,10.]),
                               step_size=0.01,
                               grad_step_size=0.00001)

# %%
eps = 0.00001
num_itter = 0
previous_x = grad_descent.x + eps + 1

while not x_norm_stop(grad_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = grad_descent.x
    grad_descent.zero_grad()
    # Compute gradient
    grad_descent.backward()
    # x_k+1 = x_k + h_k
    grad_descent.step()
    grad_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [7.799  7.2091 9.8001]
# Current f(x): 1485.9885783270622
# Current grad: [220.1       279.0899999  19.99     ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 2
# Current x: [6.0824991 5.1998701 9.6041701]
# Current f(x): 872.8123886763333
# Current grad: [171.650091  200.9229899  19.5929909]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 3
# Current x: [4.7438293 3.7533943 9.4121387]
# Current f(x): 529.7523277356087
# Current grad: [133.8669787 144.6475837  19.2031403]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 4
# Current x: [3.6998115 2.7120636 9.2239334]
# Current f(x): 335.9929141694834
# Current grad: [104.4017786 104.1330656  18.820524 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 5
# Current x: [2.8855818 1.9624081 9.0394819]
# Current f(x): 225.2957521482421
# Current grad: [81.422974  74.9655552 18.4451548]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 6
# Current x: [2.2505575 1.4227356 8.8587119]
# Current f(x): 161.12703215125885
# Current grad: [63.5024232 53.9672419 18.0770014]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 7
# Current x: [1.7552926 1.0342332 8.6815519]
# Current f(x): 123.210794620203
# Current grad: [49.5264934 38.8502447 17.716001 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 8
# Current x: [1.3690248 0.7545592 8.5079312]
# Current f(x): 100.2217963602053
# Current grad: [38.6267798 27.9674007 17.3620695]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 9
# Current x: [1.0677639 0.5532308 8.3377801]
# Current f(x): 85.79285819205685
# Current grad: [30.1260915 20.1328395 17.0151078]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 10
# Current x: [0.8328005 0.4083028 8.17103  ]
# Current f(x): 76.32057297244151
# Current grad: [23.4963381 14.4928019 16.675007 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 11
# Current x: [0.6495436 0.3039764 8.0076135]
# Current f(x): 69.75203684486009
# Current grad: [18.3256944 10.4326345 16.3416518]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 12
# Current x: [0.5066136 0.2288781 7.8474643]
# Current f(x): 64.90980447787595
# Current grad: [14.2929984  7.5098277 16.0149231]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 13
# Current x: [0.3951357 0.1748201 7.6905173]
# Current f(x): 61.113905777224254
# Current grad: [11.1477878  5.4058068 15.6946997]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 14
# Current x: [0.3081884 0.1359078 7.5367087]
# Current f(x): 57.968838602395486
# Current grad: [ 8.6947339  3.8912231 15.3808598]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 15
# Current x: [0.2403733 0.1078982 7.3859759]
# Current f(x): 55.24276492968305
# Current grad: [ 6.7815033  2.8009649 15.0732815]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 16
# Current x: [0.1874804 0.0877365 7.2382574]
# Current f(x): 52.79856936767751
# Current grad: [ 5.2892925  2.0161673 14.7718439]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 17
# Current x: [0.146226  0.0732239 7.0934932]
# Current f(x): 50.554275752081786
# Current grad: [ 4.1254465  1.4512593 14.4764271]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 18
# Current x: [0.1140489 0.0627775 6.951624 ]
# Current f(x): 48.46018736007627
# Current grad: [ 3.2177032  1.0446389 14.1869131]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 19
# Current x: [0.0889519 0.0552579 6.8125922]
# Current f(x): 46.48561196120739
# Current grad: [ 2.509704   0.7519601 13.9031853]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 20
# Current x: [0.0693769 0.0498449 6.6763409]
# Current f(x): 44.611112559684706
# Current grad: [ 1.9574939  0.5412993 13.6251291]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 21
# Current x: [0.054109  0.0459482 6.5428146]
# Current f(x): 42.82396151721501
# Current grad: [ 1.5267911  0.389676  13.3526319]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 22
# Current x: [0.0422004 0.0431427 6.4119587]
# Current f(x): 41.11546150484496
# Current grad: [ 1.1908581  0.2805476 13.0855832]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 23
# Current x: [0.032912  0.0411227 6.28372  ]
# Current f(x): 39.4793597032778
# Current grad: [ 0.9288413  0.202006  12.8238743]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 24
# Current x: [0.0256673 0.0396679 6.158046 ]
# Current f(x): 37.91090511799565
# Current grad: [ 0.724476   0.1454797 12.5673989]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 25
# Current x: [0.0200165 0.0386199 6.0348855]
# Current f(x): 36.406285782926226
# Current grad: [ 0.5650767  0.1047986 12.3160523]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 26
# Current x: [0.015609  0.0378647 5.9141882]
# Current f(x): 34.962291215242345
# Current grad: [ 0.4407494  0.0755217 12.0697323]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 27
# Current x: [0.0121712 0.0373201 5.7959048]
# Current f(x): 33.57610889793137
# Current grad: [ 0.343777   0.0544522 11.8283385]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 28
# Current x: [0.0094898 0.0369272 5.6799871]
# Current f(x): 32.24520076679767
# Current grad: [ 0.2681406  0.0392895 11.5917722]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 29
# Current x: [0.0073984 0.0366435 5.5663877]
# Current f(x): 30.96722760193865
# Current grad: [ 0.2091457  0.0283775 11.3599372]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 30
# Current x: [0.0057671 0.0364382 5.4550603]
# Current f(x): 29.740002188973985
# Current grad: [ 0.1631308  0.0205245 11.1327387]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 31
# Current x: [0.0044947 0.0362895 5.3459595]
# Current f(x): 28.56145981315976
# Current grad: [ 0.12724    0.0148727 10.9100842]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 32
# Current x: [0.0035022 0.0361814 5.2390406]
# Current f(x): 27.429639232886313
# Current grad: [ 0.0992457  0.0108047 10.6918826]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 33
# Current x: [0.0027281 0.0361027 5.1342602]
# Current f(x): 26.34267001699491
# Current grad: [ 0.0774106  0.0078764 10.4780451]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 34
# Current x: [0.0021243 0.036045  5.0315753]
# Current f(x): 25.298763767870913
# Current grad: [ 0.0603795  0.005768  10.2684842]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 35
# Current x: [0.0016534 0.0360025 4.9309442]
# Current f(x): 24.29620773715872
# Current grad: [ 0.0470954  0.0042496 10.0631146]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 36
# Current x: [0.001286  0.0359709 4.8323257]
# Current f(x): 23.333359930153073
# Current grad: [0.036734  0.0031557 9.8618524]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 37
# Current x: [0.0009995 0.0359473 4.7356795]
# Current f(x): 22.408645152487853
# Current grad: [0.0286522 0.002367  9.6646154]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 38
# Current x: [0.000776  0.0359293 4.6409663]
# Current f(x): 21.520551666503508
# Current grad: [0.0223485 0.001798  9.4713231]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 39
# Current x: [0.0006017 0.0359154 4.5481473]
# Current f(x): 20.667628254474575
# Current grad: [0.0174316 0.0013871 9.2818966]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 40
# Current x: [0.0004657 0.0359045 4.4571847]
# Current f(x): 19.84848156496645
# Current grad: [0.0135965 0.0010898 9.0962587]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 41
# Current x: [0.0003597 0.0358958 4.3680414]
# Current f(x): 19.06177366499317
# Current grad: [0.0106052 0.0008742 8.9143335]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 42
# Current x: [0.000277  0.0358886 4.2806809]
# Current f(x): 18.306219750726676
# Current grad: [0.008272  0.0007175 8.7360469]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 43
# Current x: [0.0002124 0.0358826 4.1950677]
# Current f(x): 17.580585985812135
# Current grad: [0.0064521 0.0006032 8.561326 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 44
# Current x: [0.0001621 0.0358774 4.1111667]
# Current f(x): 16.88368744814468
# Current grad: [0.0050325 0.0005192 8.3900994]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 45
# Current x: [0.0001229 0.0358728 4.0289437]
# Current f(x): 16.214386171558562
# Current grad: [0.0039253 0.0004572 8.2222975]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 46
# Current x: [0.0000922 0.0358687 3.9483652]
# Current f(x): 15.571589273351965
# Current grad: [0.0030617 0.0004111 8.0578515]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 47
# Current x: [0.0000684 0.0358649 3.8693982]
# Current f(x): 14.954247161223183
# Current grad: [0.0023881 0.0003762 7.8966945]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 48
# Current x: [0.0000497 0.0358614 3.7920106]
# Current f(x): 14.361351814164111
# Current grad: [0.0018627 0.0003496 7.7387606]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 49
# Current x: [0.0000352 0.0358582 3.7161708]
# Current f(x): 13.79193513327251
# Current grad: [0.0014529 0.0003289 7.5839854]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 50
# Current x: [0.0000239 0.035855  3.6418477]
# Current f(x): 13.245067359131811
# Current grad: [0.0011332 0.0003125 7.4323057]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 51
# Current x: [0.000015  0.035852  3.5690111]
# Current f(x): 12.719855552466662
# Current grad: [0.0008839 0.0002992 7.2836596]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 52
# Current x: [0.0000081 0.0358492 3.4976313]
# Current f(x): 12.215442135397456
# Current grad: [0.0006894 0.0002882 7.1379864]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 53
# Current x: [0.0000028 0.0358464 3.427679 ]
# Current f(x): 11.731003490756434
# Current grad: [0.0005377 0.0002788 6.9952267]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 54
# Current x: [-0.0000014  0.0358437  3.3591258]
# Current f(x): 11.265748616987631
# Current grad: [0.0004194 0.0002706 6.8553221]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 55
# Current x: [-0.0000047  0.035841   3.2919436]
# Current f(x): 10.818917836421827
# Current grad: [0.0003271 0.0002634 6.7182157]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 56
# Current x: [-0.0000072  0.0358385  3.2261051]
# Current f(x): 10.389781554759058
# Current grad: [0.0002551 0.0002568 6.5838514]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 57
# Current x: [-0.0000092  0.035836   3.1615834]
# Current f(x): 9.97763906973246
# Current grad: [0.0001989 0.0002507 6.4521744]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 58
# Current x: [-0.0000108  0.0358335  3.098352 ]
# Current f(x): 9.581817426924607
# Current grad: [0.0001552 0.000245  6.3231309]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 59
# Current x: [-0.000012   0.0358311  3.0363854]
# Current f(x): 9.201670320946404
# Current grad: [0.000121  0.0002396 6.1966683]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 60
# Current x: [-0.0000129  0.0358288  2.975658 ]
# Current f(x): 8.836577040125297
# Current grad: [0.0000944 0.0002345 6.0727349]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 61
# Current x: [-0.0000137  0.0358265  2.9161452]
# Current f(x): 8.485941452982223
# Current grad: [0.0000736 0.0002295 5.9512802]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 62
# Current x: [-0.0000143  0.0358242  2.8578227]
# Current f(x): 8.1491910348399
# Current grad: [0.0000574 0.0002248 5.8322546]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 63
# Current x: [-0.0000147  0.035822   2.8006666]
# Current f(x): 7.825775933010925
# Current grad: [0.0000447 0.0002202 5.7156095]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 64
# Current x: [-0.000015   0.0358199  2.7446536]
# Current f(x): 7.515168068978279
# Current grad: [0.0000349 0.0002157 5.6012973]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 65
# Current x: [-0.0000153  0.0358177  2.6897609]
# Current f(x): 7.216860276134056
# Current grad: [0.0000272 0.0002113 5.4892714]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 66
# Current x: [-0.0000155  0.0358157  2.635966 ]
# Current f(x): 6.930365471662432
# Current grad: [0.0000212 0.000207  5.379486 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 67
# Current x: [-0.0000157  0.0358136  2.5832471]
# Current f(x): 6.655215861232174
# Current grad: [0.0000165 0.0002028 5.2718962]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 68
# Current x: [-0.0000158  0.0358117  2.5315825]
# Current f(x): 6.390962175169448
# Current grad: [0.0000128 0.0001988 5.1664583]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 69
# Current x: [-0.0000159  0.0358097  2.4809512]
# Current f(x): 6.1371729348771416
# Current grad: [0.00001   0.0001948 5.0631291]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 70
# Current x: [-0.000016   0.0358078  2.4313325]
# Current f(x): 5.893433748309653
# Current grad: [0.0000078 0.0001909 4.9618666]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 71
# Current x: [-0.0000161  0.0358059  2.3827062]
# Current f(x): 5.659346633345487
# Current grad: [0.000006  0.000187  4.8626292]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 72
# Current x: [-0.0000161  0.0358041  2.3350525]
# Current f(x): 5.434529367958679
# Current grad: [0.0000047 0.0001833 4.7653767]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 73
# Current x: [-0.0000161  0.0358023  2.2883518]
# Current f(x): 5.218614866112367
# Current grad: [0.0000036 0.0001796 4.6700691]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 74
# Current x: [-0.0000162  0.0358005  2.2425851]
# Current f(x): 5.011250578377793
# Current grad: [0.0000028 0.000176  4.5766677]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 75
# Current x: [-0.0000162  0.0357988  2.1977338]
# Current f(x): 4.8120979162795985
# Current grad: [0.0000022 0.0001725 4.4851344]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 76
# Current x: [-0.0000162  0.0357971  2.1537794]
# Current f(x): 4.620831699448188
# Current grad: [0.0000017 0.0001691 4.3954317]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 77
# Current x: [-0.0000162  0.0357955  2.1107042]
# Current f(x): 4.43713962465992
# Current grad: [0.0000013 0.0001657 4.3075231]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 78
# Current x: [-0.0000162  0.0357938  2.0684905]
# Current f(x): 4.260721755896731
# Current grad: [0.000001  0.0001624 4.2213726]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 79
# Current x: [-0.0000162  0.0357923  2.027121 ]
# Current f(x): 4.09129003460384
# Current grad: [0.0000008 0.0001591 4.1369452]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 80
# Current x: [-0.0000162  0.0357907  1.986579 ]
# Current f(x): 3.9285678093462666
# Current grad: [0.0000006 0.0001559 4.0542063]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 81
# Current x: [-0.0000163  0.0357892  1.9468477]
# Current f(x): 3.7722893840850804
# Current grad: [0.0000004 0.0001528 3.9731221]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 82
# Current x: [-0.0000163  0.0357877  1.9079111]
# Current f(x): 3.622199584346459
# Current grad: [0.0000003 0.0001498 3.8936597]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 83
# Current x: [-0.0000163  0.0357862  1.8697533]
# Current f(x): 3.478053340564957
# Current grad: [0.0000002 0.0001468 3.8157865]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 84
# Current x: [-0.0000163  0.0357848  1.8323586]
# Current f(x): 3.3396152879288774
# Current grad: [0.0000002 0.0001438 3.7394708]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration:

# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 434
# Current x: [-0.0000162  0.0357144  0.0015743]
# Current f(x): -0.017854723565012474
# Current grad: [-0.         0.0000001  0.0031764]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 435
# Current x: [-0.0000162  0.0357144  0.0015432]
# Current f(x): -0.017854819496402507
# Current grad: [-0.         0.0000001  0.0031129]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 436
# Current x: [-0.0000162  0.0357143  0.0015127]
# Current f(x): -0.01785491162890957
# Current grad: [-0.         0.0000001  0.0030506]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 437
# Current x: [-0.0000162  0.0357143  0.0014828]
# Current f(x): -0.017855000112969414
# Current grad: [-0.         0.0000001  0.0029896]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 438
# Current x: [-0.0000162  0.0357143  0.0014535]
# Current f(x): -0.017855085093060555
# Current grad: [-0.         0.0000001  0.0029298]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 439
# Current x: [-0.0000162  0.0357143  0.0014248]
# Current f(x): -0.017855166707940164
# Current grad: [-0.         0.0000001  0.0028712]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 440
# Current x: [-0.0000162  0.0357143  0.0013966]
# Current f(x): -0.01785524509087059
# Current grad: [-0.         0.0000001  0.0028138]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 441
# Current x: [-0.0000162  0.0357143  0.001369 ]
# Current f(x): -0.017855320369837027
# Current grad: [-0.         0.0000001  0.0027575]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 442
# Current x: [-0.0000162  0.0357143  0.001342 ]
# Current f(x): -0.017855392667756455
# Current grad: [-0.         0.0000001  0.0027024]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 443
# Current x: [-0.0000162  0.0357143  0.0013155]
# Current f(x): -0.01785546210267832
# Current grad: [-0.         0.0000001  0.0026483]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 444
# Current x: [-0.0000162  0.0357143  0.0012896]
# Current f(x): -0.01785552878797734
# Current grad: [-0.         0.0000001  0.0025954]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 445
# Current x: [-0.0000162  0.0357143  0.0012641]
# Current f(x): -0.01785559283253857
# Current grad: [-0.         0.0000001  0.0025435]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 446
# Current x: [-0.0000162  0.0357143  0.0012392]
# Current f(x): -0.01785565434093522
# Current grad: [-0.         0.0000001  0.0024926]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 447
# Current x: [-0.0000162  0.0357143  0.0012148]
# Current f(x): -0.017855713413599407
# Current grad: [-0.         0.0000001  0.0024427]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 448
# Current x: [-0.0000162  0.0357143  0.0011909]
# Current f(x): -0.017855770146986145
# Current grad: [-0.         0.0000001  0.0023939]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 449
# Current x: [-0.0000162  0.0357143  0.0011674]
# Current f(x): -0.017855824633730807
# Current grad: [-0.         0.0000001  0.002346 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 450
# Current x: [-0.0000162  0.0357143  0.0011444]
# Current f(x): -0.017855876962800422
# Current grad: [-0.         0.0000001  0.0022991]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 451
# Current x: [-0.0000162  0.0357143  0.0011219]
# Current f(x): -0.01785592721963892
# Current grad: [-0.         0.0000001  0.0022531]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 452
# Current x: [-0.0000162  0.0357143  0.0010998]
# Current f(x): -0.01785597548630665
# Current grad: [-0.         0.0000001  0.002208 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 453
# Current x: [-0.0000162  0.0357143  0.0010782]
# Current f(x): -0.017856021841614375
# Current grad: [-0.         0.0000001  0.0021639]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 454
# Current x: [-0.0000162  0.0357143  0.0010569]
# Current f(x): -0.017856066361251942
# Current grad: [-0.         0.0000001  0.0021206]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 455
# Current x: [-0.0000162  0.0357143  0.0010362]
# Current f(x): -0.0178561091179119
# Current grad: [-0.         0.0000001  0.0020782]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 456
# Current x: [-0.0000162  0.0357143  0.0010158]
# Current f(x): -0.01785615018140816
# Current grad: [-0.         0.0000001  0.0020366]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 457
# Current x: [-0.0000162  0.0357143  0.0009958]
# Current f(x): -0.01785618961879
# Current grad: [-0.         0.0000001  0.0019959]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 458
# Current x: [-0.0000162  0.0357143  0.0009763]
# Current f(x): -0.01785622749445154
# Current grad: [-0.         0.0000001  0.001956 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 459
# Current x: [-0.0000162  0.0357143  0.0009571]
# Current f(x): -0.017856263870236918
# Current grad: [-0.         0.0000001  0.0019169]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 460
# Current x: [-0.0000162  0.0357143  0.0009383]
# Current f(x): -0.01785629880554122
# Current grad: [-0.         0.0000001  0.0018785]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 461
# Current x: [-0.0000162  0.0357143  0.0009199]
# Current f(x): -0.017856332357407495
# Current grad: [-0.         0.0000001  0.0018409]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 462
# Current x: [-0.0000162  0.0357143  0.0009019]
# Current f(x): -0.0178563645806199
# Current grad: [-0.         0.0000001  0.0018041]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 463
# Current x: [-0.0000162  0.0357143  0.0008842]
# Current f(x): -0.01785639552779311
# Current grad: [-0.         0.0000001  0.001768 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 464
# Current x: [-0.0000162  0.0357143  0.0008669]
# Current f(x): -0.01785642524945829
# Current grad: [-0.         0.0000001  0.0017327]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 465
# Current x: [-0.0000162  0.0357143  0.0008499]
# Current f(x): -0.017856453794145542
# Current grad: [-0.         0.0000001  0.001698 ]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 466
# Current x: [-0.0000162  0.0357143  0.0008333]
# Current f(x): -0.01785648120846321
# Current grad: [-0.         0.0000001  0.0016641]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 467
# Current x: [-0.0000162  0.0357143  0.0008169]
# Current f(x): -0.017856507537173914
# Current grad: [-0.         0.0000001  0.0016308]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 468
# Current x: [-0.0000162  0.0357143  0.000801 ]
# Current f(x): -0.0178565328232677
# Current grad: [-0.         0.0000001  0.0015982]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 469
# Current x: [-0.0000162  0.0357143  0.0007853]
# Current f(x): -0.01785655710803219
# Current grad: [-0.         0.0000001  0.0015662]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 470
# Current x: [-0.0000162  0.0357143  0.00077  ]
# Current f(x): -0.01785658043112002
# Current grad: [-0.         0.0000001  0.0015349]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 471
# Current x: [-0.0000162  0.0357143  0.0007549]
# Current f(x): -0.017856602830613588
# Current grad: [-0.         0.0000001  0.0015042]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 472
# Current x: [-0.0000162  0.0357143  0.0007402]
# Current f(x): -0.01785662434308723
# Current grad: [-0.         0.0000001  0.0014741]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 473
# Current x: [-0.0000162  0.0357143  0.0007257]
# Current f(x): -0.017856645003666936
# Current grad: [-0.         0.0000001  0.0014446]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 474
# Current x: [-0.0000162  0.0357143  0.0007116]
# Current f(x): -0.01785666484608769
# Current grad: [-0.         0.0000001  0.0014157]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 475
# Current x: [-0.0000162  0.0357143  0.0006977]
# Current f(x): -0.017856683902748607
# Current grad: [-0.         0.0000001  0.0013874]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 476
# Current x: [-0.0000162  0.0357143  0.0006841]
# Current f(x): -0.017856702204765762
# Current grad: [-0.         0.0000001  0.0013597]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 477
# Current x: [-0.0000162  0.0357143  0.0006708]
# Current f(x): -0.017856719782023044
# Current grad: [-0.         0.0000001  0.0013325]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 478
# Current x: [-0.0000162  0.0357143  0.0006577]
# Current f(x): -0.017856736663220966
# Current grad: [-0.         0.0000001  0.0013058]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 479
# Current x: [-0.0000162  0.0357143  0.0006449]
# Current f(x): -0.01785675287592346
# Current grad: [-0.         0.         0.0012797]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 480
# Current x: [-0.0000162  0.0357143  0.0006324]
# Current f(x): -0.017856768446602944
# Current grad: [-0.         0.         0.0012541]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 481
# Current x: [-0.0000162  0.0357143  0.0006201]
# Current f(x): -0.017856783400683536
# Current grad: [-0.        0.        0.001229]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 482
# Current x: [-0.0000162  0.0357143  0.000608 ]
# Current f(x): -0.01785679776258254
# Current grad: [-0.         0.         0.0012044]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 483
# Current x: [-0.0000162  0.0357143  0.0005962]
# Current f(x): -0.017856811555750352
# Current grad: [-0.         0.         0.0011804]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 484
# Current x: [-0.0000162  0.0357143  0.0005847]
# Current f(x): -0.01785682480270874
# Current grad: [-0.         0.         0.0011568]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 485
# Current x: [-0.0000162  0.0357143  0.0005733]
# Current f(x): -0.017856837525087585
# Current grad: [-0.         0.         0.0011336]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 486
# Current x: [-0.0000162  0.0357143  0.0005622]
# Current f(x): -0.01785684974366023
# Current grad: [-0.         0.         0.0011109]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 487
# Current x: [-0.0000162  0.0357143  0.0005513]
# Current f(x): -0.017856861478377412
# Current grad: [-0.         0.         0.0010887]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 488
# Current x: [-0.0000162  0.0357143  0.0005407]
# Current f(x): -0.017856872748399803
# Current grad: [-0.        0.        0.001067]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 489
# Current x: [-0.0000162  0.0357143  0.0005302]
# Current f(x): -0.01785688357212931
# Current grad: [-0.         0.         0.0010456]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 490
# Current x: [-0.0000162  0.0357143  0.00052  ]
# Current f(x): -0.01785689396723914
# Current grad: [-0.         0.         0.0010247]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 491
# Current x: [-0.0000162  0.0357143  0.0005099]
# Current f(x): -0.017856903950702628
# Current grad: [-0.         0.         0.0010042]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Itteration: 492
# Current x: [-0.0000162  0.0357143  0.0005001]
# Current f(x): -0.017856913538820976
# Current grad: [-0.         0.         0.0009841]
# Step size: 0.01
# Gradient step size: 1e-05
#
# Converged in 492 itterations

# %% [markdown]
# Застосуємо метод з адаптивною величиною кроку

# %%
grad_descent = GradientDescent(target_func=target_function,
                               initial_x=np.array([10.,10.,10.]),
                               step_size=1,
                               grad_step_size=0.00001,
                               adaptive_beta=0.5)

# %%
eps = 0.00001
num_itter = 0
previous_x = grad_descent.x + eps + 1

while not x_norm_stop(grad_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = grad_descent.x
    grad_descent.zero_grad()
    # Compute gradient
    grad_descent.backward()
    # x_k+1 = x_k + h_k
    grad_descent.step()
    grad_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [-3.75625  -7.443125  8.750625]
# Current f(x): 1015.1663677337114
# Current grad: [220.1       279.0899999  19.99     ]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 2
# Current x: [1.4132457 5.6477383 7.6563317]
# Current f(x): 521.53542286233
# Current grad: [ -82.7119312 -209.453813    17.5086931]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 3
# Current x: [-0.533497  -4.1737085  6.6996432]
# Current f(x): 296.11776221167185
# Current grad: [ 31.1478828 157.143149   15.3070156]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 4
# Current x: [0.2026699 3.1935335 5.8619269]
# Current f(x): 174.389422278079
# Current grad: [ -11.7786705 -117.8758725   13.4034601]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 5
# Current x: [-0.0779972 -2.3324104  5.1293857]
# Current f(x): 104.88564909652312
# Current grad: [ 4.4906739 88.4151037 11.7206604]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 6
# Current x: [0.0307067 1.8121772 4.4880667]
# Current f(x): 64.30916605952237
# Current grad: [ -1.7392621 -66.3134019  10.2611038]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 7
# Current x: [-0.0126476 -1.2963716  3.9271716]
# Current f(x): 40.254172402822746
# Current grad: [ 0.6936692 49.7367798  8.9743212]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 8
# Current x: [0.0055531 1.035032  3.4361941]
# Current f(x): 25.767316421951644
# Current grad: [ -0.2912114 -37.3024575   7.8556396]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 9
# Current x: [-0.0027293 -0.7135627  3.0067346]
# Current f(x): 16.8846671219654
# Current grad: [ 0.1325183 27.9775161  6.8713532]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 10
# Current x: [0.0014695 0.5978617 2.6308481]
# Current f(x): 11.326100067378093
# Current grad: [ -0.0671803 -20.9827904   6.0141827]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 11
# Current x: [-0.0009247 -0.3857327  2.3020295]
# Current f(x): 7.7690299836208085
# Current grad: [ 0.0383069 15.7375107  5.2610984]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 12
# Current x: [0.0005879 0.351944  2.0142517]
# Current f(x): 5.438667097954845
# Current grad: [ -0.024201  -11.8028282   4.6044447]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 13
# Current x: [-0.0004404 -0.2013325  1.7624922]
# Current f(x): 3.8755560061205427
# Current grad: [0.0164521 8.852424  4.0281515]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 14
# Current x: [0.000291  0.2136098 1.5421681]
# Current f(x): 2.8031528742457894
# Current grad: [-0.0117023 -6.6390765  3.5251858]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 15
# Current x: [-0.0002426 -0.0976111  1.3494105]
# Current f(x): 2.052043416739954
# Current grad: [0.0085378 4.979535  3.0841226]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 16
# Current x: [0.000152  0.1357928 1.180728 ]
# Current f(x): 1.5163217647254497
# Current grad: [-0.0063139 -3.7344639  2.6989185]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 17
# Current x: [-0.0001419 -0.0392709  1.0331455]
# Current f(x): 1.1282923568587413
# Current grad: [0.0047017 2.8010205 2.3613203]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 18
# Current x: [0.0002974 0.2233067 0.7748542]
# Current f(x): 1.0750431292666238
# Current grad: [-0.0035138 -2.1006207  2.0663303]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 19
# Current x: [-0.0002511 -0.1049318  0.6780114]
# Current f(x): 0.7188527452401592
# Current grad: [0.0087749 5.2518146 1.5494852]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 20
# Current x: [0.0001597 0.1412413 0.5932534]
# Current f(x): 0.4899126496819344
# Current grad: [-0.006573  -3.9387696  1.3561278]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 21
# Current x: [-0.0001482 -0.043394   0.5191056]
# Current f(x): 0.3392500515000423
# Current grad: [0.0049266 2.954166  1.1863656]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 22
# Current x: [0.0000827 0.0950781 0.4542147]
# Current f(x): 0.23774759837561532
# Current grad: [-0.0036938 -2.2155535  1.0382546]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 23
# Current x: [-0.0000904 -0.0087802  0.3974438]
# Current f(x): 0.16782464103780237
# Current grad: [0.0027699 1.6617323 0.9083343]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 24
# Current x: [0.0000394 0.0691101 0.3477628]
# Current f(x): 0.11867168428575946
# Current grad: [-0.0020773 -1.2462442  0.7948963]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 25
# Current x: [-0.000058   0.0106892  0.3042967]
# Current f(x): 0.08350372528941216
# Current grad: [0.0015579 0.9347341 0.6954564]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 26
# Current x: [0.0000151 0.0545022 0.2662603]
# Current f(x): 0.0579646956147212
# Current grad: [-0.0011684 -0.7010081  0.6085828]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 27
# Current x: [-0.0000945 -0.0112222  0.199702 ]
# Current f(x): 0.05286855601116542
# Current grad: [0.0008763 0.5257948 0.5324661]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 28
# Current x: [0.0000424 0.0709292 0.1747386]
# Current f(x): 0.030025323654420552
# Current grad: [-0.0021907 -1.3144216  0.3994153]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 29
# Current x: [-0.0000602  0.009314   0.1529007]
# Current f(x): 0.015277731070229818
# Current grad: [0.001643  0.9858426 0.3494062]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 30
# Current x: [0.0000168 0.0555241 0.1337887]
# Current f(x): 0.005528848202678724
# Current grad: [-0.0012323 -0.7393611  0.3057921]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 31
# Current x: [-0.000041   0.0208653  0.1170686]
# Current f(x): -0.0010676263122009443
# Current grad: [0.0009242 0.5545407 0.2675219]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 32
# Current x: [0.0000023 0.0468584 0.1024363]
# Current f(x): -0.00563007417276179
# Current grad: [-0.0006932 -0.4158894  0.2341163]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 33
# Current x: [-0.0000302  0.0273626  0.0896347]
# Current f(x): -0.008848709964165088
# Current grad: [0.0005199 0.3119321 0.2048258]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 34
# Current x: [-0.0000058  0.0419837  0.0784321]
# Current f(x): -0.01115857786692864
# Current grad: [-0.0003899 -0.2339366  0.179242 ]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 35
# Current x: [-0.0000241  0.0310172  0.0686307]
# Current f(x): -0.012840220169942091
# Current grad: [0.0002924 0.1754639 0.1568222]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 36
# Current x: [0.0000033 0.0474657 0.0514769]
# Current f(x): -0.013276373403271438
# Current grad: [-0.0002193 -0.1315883  0.1372304]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 37
# Current x: [-0.0000309  0.0269039  0.0450452]
# Current f(x): -0.014742567425777318
# Current grad: [0.0005483 0.3289882 0.1029063]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 38
# Current x: [-0.0000052  0.0423249  0.0394163]
# Current f(x): -0.015693371087238516
# Current grad: [-0.0004112 -0.2467351  0.0900636]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 39
# Current x: [-0.0000245  0.0307588  0.0344919]
# Current f(x): -0.016324719857522867
# Current grad: [0.0003084 0.1850572 0.0787902]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 40
# Current x: [-0.00001    0.0394331  0.0301823]
# Current f(x): -0.01675375282467435
# Current grad: [-0.0002313 -0.1387882  0.068953 ]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 41
# Current x: [-0.0000209  0.0329271  0.026412 ]
# Current f(x): -0.017051662923111322
# Current grad: [0.0001735 0.1040956 0.0603252]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 42
# Current x: [-0.0000127  0.0378063  0.0231126]
# Current f(x): -0.017262555644381738
# Current grad: [-0.0001301 -0.078068   0.0527911]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 43
# Current x: [-0.0000188  0.0341467  0.0202258]
# Current f(x): -0.017414348339820536
# Current grad: [0.0000976 0.0585544 0.0461873]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 44
# Current x: [-0.0000143  0.0368913  0.0176998]
# Current f(x): -0.01752512408234918
# Current grad: [-0.0000732 -0.043913   0.0404175]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 45
# Current x: [-0.0000211  0.0327741  0.0132794]
# Current f(x): -0.017560210698326993
# Current grad: [0.0000549 0.0329373 0.0353626]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 46
# Current x: [-0.0000126  0.0379203  0.0116215]
# Current f(x): -0.017654396921087497
# Current grad: [-0.0001372 -0.0823389  0.0265261]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 47
# Current x: [-0.000019   0.0340605  0.0101712]
# Current f(x): -0.017715749288931663
# Current grad: [0.0001029 0.0617559 0.0232052]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 48
# Current x: [-0.0000142  0.0369553  0.0089019]
# Current f(x): -0.017756670264335004
# Current grad: [-0.0000772 -0.0463155  0.0203084]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 49
# Current x: [-0.0000178  0.0347841  0.0077915]
# Current f(x): -0.01778459616536168
# Current grad: [0.0000579 0.034738  0.0177669]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 50
# Current x: [-0.0000151  0.0364124  0.0068197]
# Current f(x): -0.01780406205384301
# Current grad: [-0.0000434 -0.0260524  0.0155482]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 51
# Current x: [-0.0000171  0.0351911  0.0059696]
# Current f(x): -0.017817888502014434
# Current grad: [0.0000326 0.0195403 0.0136031]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 52
# Current x: [-0.0000156  0.036107   0.0052256]
# Current f(x): -0.01782786849320374
# Current grad: [-0.0000244 -0.0146544  0.0119039]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 53
# Current x: [-0.0000179  0.0347331  0.0039237]
# Current f(x): -0.01782840807008326
# Current grad: [0.0000183 0.0109916 0.010415 ]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 54
# Current x: [-0.000015   0.0364504  0.0034354]
# Current f(x): -0.017837882215858858
# Current grad: [-0.0000458 -0.0274776  0.0078126]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 55
# Current x: [-0.0000172  0.0351624  0.0030082]
# Current f(x): -0.017843937692290337
# Current grad: [0.0000343 0.0206087 0.0068343]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 56
# Current x: [-0.0000155  0.0361284  0.0026344]
# Current f(x): -0.017847899945943914
# Current grad: [-0.0000258 -0.0154561  0.0059813]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 57
# Current x: [-0.0000168  0.0354039  0.0023074]
# Current f(x): -0.017850554436944232
# Current grad: [0.0000193 0.0115925 0.0052327]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 58
# Current x: [-0.0000158  0.0359473  0.0020212]
# Current f(x): -0.017852373531956952
# Current grad: [-0.0000145 -0.0086941  0.0045793]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 59
# Current x: [-0.0000165  0.0355397  0.0017708]
# Current f(x): -0.0178536463233101
# Current grad: [0.0000109 0.0065208 0.0040064]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 60
# Current x: [-0.000016   0.0358453  0.0015516]
# Current f(x): -0.017854553330290856
# Current grad: [-0.0000082 -0.0048904  0.003506 ]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 61
# Current x: [-0.0000164  0.0356161  0.0013599]
# Current f(x): -0.01785520980333746
# Current grad: [0.0000061 0.003668  0.0030674]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 62
# Current x: [-0.0000158  0.0359599  0.0010244]
# Current f(x): -0.017855288335703778
# Current grad: [-0.0000046 -0.0027508  0.0026842]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 63
# Current x: [-0.0000165  0.0355301  0.0008986]
# Current f(x): -0.017855895301446035
# Current grad: [0.0000115 0.0068774 0.0020128]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 64
# Current x: [-0.000016   0.0358525  0.0007885]
# Current f(x): -0.01785628495318435
# Current grad: [-0.0000086 -0.0051579  0.0017617]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 65
# Current x: [-0.0000164  0.0356107  0.0006922]
# Current f(x): -0.017856541060949613
# Current grad: [0.0000064 0.0038686 0.0015411]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 66
# Current x: [-0.0000161  0.035792   0.0006079]
# Current f(x): -0.0178567133950088
# Current grad: [-0.0000048 -0.0029013  0.0013487]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 67
# Current x: [-0.0000163  0.035656   0.0005341]
# Current f(x): -0.017856831979733503
# Current grad: [0.0000036 0.0021761 0.00118  ]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 68
# Current x: [-0.0000162  0.035758   0.0004696]
# Current f(x): -0.017856915256964073
# Current grad: [-0.0000027 -0.001632   0.0010326]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 69
# Current x: [-0.0000163  0.0356815  0.0004131]
# Current f(x): -0.017856974789344983
# Current grad: [0.000002  0.0012241 0.0009034]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 70
# Current x: [-0.0000162  0.0357389  0.0003637]
# Current f(x): -0.017857017991271366
# Current grad: [-0.0000015 -0.000918   0.0007906]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 71
# Current x: [-0.0000163  0.0356528  0.0002773]
# Current f(x): -0.01785702588151407
# Current grad: [0.0000011 0.0006885 0.0006917]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 72
# Current x: [-0.0000162  0.0357604  0.0002448]
# Current f(x): -0.01785706479870835
# Current grad: [-0.0000029 -0.0017213  0.0005189]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 73
# Current x: [-0.0000163  0.0356797  0.0002165]
# Current f(x): -0.0178570898929474
# Current grad: [0.0000022 0.001291  0.0004539]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 74
# Current x: [-0.0000162  0.0357402  0.0001916]
# Current f(x): -0.017857106460989314
# Current grad: [-0.0000016 -0.0009682  0.0003972]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 75
# Current x: [-0.0000163  0.0356948  0.0001699]
# Current f(x): -0.017857117658228915
# Current grad: [0.0000012 0.0007262 0.0003475]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 76
# Current x: [-0.0000162  0.0357289  0.0001509]
# Current f(x): -0.017857125394300198
# Current grad: [-0.0000009 -0.0005446  0.0003041]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 77
# Current x: [-0.0000163  0.0357034  0.0001343]
# Current f(x): -0.017857130846519853
# Current grad: [0.0000007 0.0004085 0.0002661]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 78
# Current x: [-0.0000162  0.0357225  0.0001197]
# Current f(x): -0.017857134756100485
# Current grad: [-0.0000005 -0.0003063  0.0002328]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 79
# Current x: [-0.0000162  0.0357081  0.000107 ]
# Current f(x): -0.017857137600436775
# Current grad: [0.0000004 0.0002298 0.0002037]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 80
# Current x: [-0.0000162  0.0357297  0.0000847]
# Current f(x): -0.01785713829199947
# Current grad: [-0.0000003 -0.0001723  0.0001783]
# Step size: 0.125
# Gradient step size: 1e-05
#
# Itteration: 81
# Current x: [-0.0000163  0.0357028  0.0000763]
# Current f(x): -0.017857140789331673
# Current grad: [0.0000007 0.0004308 0.0001337]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 82
# Current x: [-0.0000162  0.0357229  0.000069 ]
# Current f(x): -0.017857142406821968
# Current grad: [-0.0000005 -0.0003231  0.000117 ]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 83
# Current x: [-0.0000162  0.0357078  0.0000626]
# Current f(x): -0.01785714347953959
# Current grad: [0.0000004 0.0002423 0.0001024]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 84
# Current x: [-0.0000162  0.0357192  0.000057 ]
# Current f(x): -0.017857144207647474
# Current grad: [-0.0000003 -0.0001817  0.0000896]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Itteration: 85
# Current x: [-0.0000162  0.0357106  0.0000521]
# Current f(x): -0.017857144712684687
# Current grad: [0.0000002 0.0001363 0.0000784]
# Step size: 0.0625
# Gradient step size: 1e-05
#
# Converged in 85 itterations

# %% [markdown]
# ## Градієнтний спуск для квадратичної функції

# %% [markdown]
# Цільова функція - квадратична. Покращимо алгоритм з урахуванням цього факту

# %% [markdown]
# ### Загальний вигляд квадратичної функції

# %% [markdown]
# $$\frac{1}{2}(Ax,x) + (b,x)$$А - симетрична, додатньо визначена матриця

# %% [markdown]
# В нашому випадку:

# %% [markdown]
# $$A = \begin{bmatrix}
#        22   & 0,01  & 0     \\
#        0,01 & 28    & 0,001 \\
#        0    & 0,001 & 2
#      \end{bmatrix}$$

# %% [markdown]
# $$b = \begin{bmatrix}
#        0  \\
#        -1 \\
#        0
#      \end{bmatrix}$$

# %%
A_matrix = np.array([[22,0.01,0],
                     [0.01,28,-0.001],
                     [0,-0.001,2]])
b_vector = np.array([0,-1,0])

# %%
class QuadraticGradientDescent:
    
    def __init__(self, A, b, initial_x):
        self.A = A
        self.b = b
        
        # Function in matrix format
        self.f = lambda x: ((self.A@x)@x)/2 + b@x
        self.x = initial_x
        
        self.f_value = self.f(self.x)
        
        self.step_size = None
        
        self.grad = None
    
    @staticmethod
    def compute_step_size(A, b, grad,x):
        # alpha_k = (Ax + b)f(x_k)' / (Af(x_k)',f(x_k)')
        return ((A@x+b)@grad)/((A@grad)@grad)
        
    @staticmethod
    def compose_grad_vec(A, b, x):
        # f(x_k)' = Ax + b
        return A@x + b
    
    def backward(self):
        self.grad = QuadraticGradientDescent.compose_grad_vec(self.A,self.b,self.x)
        
    def zero_grad(self):
        self.grad = np.zeros(self.x.shape[0])
        
    def step(self):
        self.step_size = QuadraticGradientDescent.compute_step_size(self.A, self.b, self.grad, self.x)
        # x_k+1 = x_k - alpha_k * f(x_k)'
        self.x = self.x - self.step_size * self.grad
        self.f_value = self.f(self.x)
        
    def info(self):
        print('Current x: {}'.format(self.x))
        print('Current f(x): {}'.format(self.f_value))
        print('Current grad: {}'.format(self.grad))
        print('Step size: {}'.format(self.step_size))

# %%
quad_grad_descent = QuadraticGradientDescent(A=A_matrix,
                                             b=b_vector,
                                             initial_x=np.array([10,10,10]))

# %%
eps = 0.00001
num_itter = 0
previous_x = quad_grad_descent.x + eps + 1

while not x_norm_stop(quad_grad_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = quad_grad_descent.x
    quad_grad_descent.zero_grad()
    # Compute gradient
    quad_grad_descent.backward()
    # x_k+1 = x_k + h_k
    quad_grad_descent.step()
    quad_grad_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [ 1.4137959 -0.8874316  9.2201807]
# Current f(x): 118.90729619227575
# Current grad: [220.1  279.09  19.99]
# Step size: 0.03901046845393336
#
# Itteration: 2
# Current x: [-0.0973143  0.3684723  8.3239889]
# Current f(x): 70.92186914359814
# Current grad: [ 31.0946353 -25.8431682  18.4412489]
# Step size: 0.0485971350164743
#
# Itteration: 3
# Current x: [ 0.1582914 -0.7447252  6.3329895]
# Current f(x): 48.895255176638244
# Current grad: [-2.1372298  9.307927  16.6476093]
# Step size: 0.11959671234495632
#
# Itteration: 4
# Current x: [-0.0035475  0.2732197  5.7430644]
# Current f(x): 33.753214456411236
# Current grad: [  3.4749628 -21.8570551  12.6667238]
# Step size: 0.04657283021378687
#
# Itteration: 5
# Current x: [ 0.0052934 -0.5067607  4.3947444]
# Current f(x): 23.418336717596976
# Current grad: [-0.0753125  6.6443741 11.4858555]
# Step size: 0.11738959703968287
#
# Itteration: 6
# Current x: [0.000108  0.2005508 3.9855426]
# Current f(x): 16.24628904899507
# Current grad: [  0.1113876 -15.1936403   8.7899956]
# Step size: 0.04655312659263508
#
# Itteration: 7
# Current x: [-0.0004063 -0.3407516  3.0498997]
# Current f(x): 11.269245766445557
# Current grad: [0.004381  4.6114379 7.9708847]
# Step size: 0.1173825672084297
#
# Itteration: 8
# Current x: [0.0001684 0.1501085 2.7659195]
# Current f(x): 7.815243489210412
# Current grad: [ -0.0123456 -10.5440994   6.1001402]
# Step size: 0.04655306565852441
#
# Itteration: 9
# Current x: [-0.0004428 -0.2255478  2.1165958]
# Current f(x): 5.418211706431899
# Current grad: [0.005207  3.2002746 5.5316889]
# Step size: 0.11738254585924929
#
# Itteration: 10
# Current x: [0.0001157 0.1151024 1.9195172]
# Current f(x): 3.7547031651383547
# Current grad: [-0.0119961 -7.3174608  4.2334171]
# Step size: 0.046553065473488336
#
# Itteration: 11
# Current x: [-0.0003182 -0.1455982  1.4688951]
# Current f(x): 2.6002501093735173
# Current grad: [0.0036964 2.2209483 3.8389194]
# Step size: 0.11738254579442281
#
# Itteration: 12
# Current x: [0.0000755 0.0908086 1.3321252]
# Current f(x): 1.7990748670883567
# Current grad: [-0.0084563 -5.0782214  2.9379358]
# Step size: 0.04655306547292648
#
# Itteration: 13
# Current x: [-0.000226  -0.0901142  1.0193994]
# Current f(x): 1.2430697825636898
# Current grad: [0.0025684 1.5413089 2.6641596]
# Step size: 0.11738254579422588
#
# Itteration: 14
# Current x: [0.0000474 0.073949  0.9244828]
# Current f(x): 0.8572095640976425
# Current grad: [-0.0058736 -3.5242189  2.0388888]
# Step size: 0.04655306547292477
#
# Itteration: 15
# Current x: [-0.0001618 -0.051609   0.7074552]
# Current f(x): 0.58942764566078
# Current grad: [0.0017826 1.0696481 1.8488917]
# Step size: 0.1173825457942254
#
# Itteration: 16
# Current x: [0.0000279 0.0622487 0.6415844]
# Current f(x): 0.40359051498482645
# Current grad: [-0.0040764 -2.4457615  1.414962 ]
# Step size: 0.04655306547292474
#
# Itteration: 17
# Current x: [-0.0001173 -0.0248869  0.4909701]
# Current f(x): 0.2746219896285702
# Current grad: [0.0012371 0.7423217 1.2831065]
# Step size: 0.11738254579422559
#
# Itteration: 18
# Current x: [0.0000144 0.0541288 0.4452566]
# Current f(x): 0.18511952867220582
# Current grad: [-0.002829  -1.6973264  0.981965 ]
# Step size: 0.04655306547292473
#
# Itteration: 19
# Current x: [-0.0000864 -0.0063422  0.3407322]
# Current f(x): 0.12300599752096425
# Current grad: [0.0008585 0.5151615 0.8904591]
# Step size: 0.11738254579422554
#
# Itteration: 20
# Current x: [0.000005  0.0484937 0.3090077]
# Current f(x): 0.07990002355274879
# Current grad: [-0.0019633 -1.1779222  0.6814708]
# Step size: 0.04655306547292472
#
# Itteration: 21
# Current x: [-0.0000649  0.0065277  0.2364692]
# Current f(x): 0.049985044363688044
# Current grad: [0.0005958 0.3575153 0.6179669]
# Step size: 0.11738254579422563
#
# Itteration: 22
# Current x: [-0.0000015  0.0445831  0.2144527]
# Current f(x): 0.029224442119975734
# Current grad: [-0.0013625 -0.8174625  0.4729318]
# Step size: 0.046553065472924725
#
# Itteration: 23
# Current x: [-0.00005    0.0154592  0.164112 ]
# Current f(x): 0.014816857117234346
# Current grad: [0.0004135 0.2481109 0.4288609]
# Step size: 0.1173825457942257
#
# Itteration: 24
# Current x: [-0.000006   0.0418691  0.1488328]
# Current f(x): 0.004818182552093216
# Current grad: [-0.0009455 -0.5673082  0.3282084]
# Step size: 0.04655306547292471
#
# Itteration: 25
# Current x: [-0.0000397  0.0216575  0.113897 ]
# Current f(x): -0.0021207661364328646
# Current grad: [0.000287  0.1721857 0.2976238]
# Step size: 0.11738254579422555
#
# Itteration: 26
# Current x: [-0.0000091  0.0399856  0.1032935]
# Current f(x): -0.006936305294979149
# Current grad: [-0.0006562 -0.3937045  0.2277723]
# Step size: 0.04655306547292473
#
# Itteration: 27
# Current x: [-0.0000325  0.0259591  0.0790485]
# Current f(x): -0.010278226157693918
# Current grad: [0.0001991 0.1194946 0.206547 ]
# Step size: 0.11738254579422572
#
# Itteration: 28
# Current x: [-0.0000113  0.0386786  0.0716898]
# Current f(x): -0.012597475297808847
# Current grad: [-0.0004554 -0.2732257  0.158071 ]
# Step size: 0.04655306547292471
#
# Itteration: 29
# Current x: [-0.0000275  0.0289443  0.0548641]
# Current f(x): -0.014207003708231568
# Current grad: [0.0001382 0.0829277 0.1433409]
# Step size: 0.1173825457942255
#
# Itteration: 30
# Current x: [-0.0000128  0.0377715  0.0497572]
# Current f(x): -0.015323995263450827
# Current grad: [-0.000316  -0.1896151  0.1096992]
# Step size: 0.04655306547292473
#
# Itteration: 31
# Current x: [-0.0000241  0.031016   0.0380804]
# Current f(x): -0.016099172716891028
# Current grad: [0.0000959 0.0575507 0.0994767]
# Step size: 0.11738254579422598
#
# Itteration: 32
# Current x: [-0.0000139  0.0371419  0.0345363]
# Current f(x): -0.016637135677769522
# Current grad: [-0.0002193 -0.1315904  0.0761298]
# Step size: 0.046553065472924676
#
# Itteration: 33
# Current x: [-0.0000217  0.0324537  0.0264328]
# Current f(x): -0.01701047489963775
# Current grad: [0.0000666 0.0399395 0.0690355]
# Step size: 0.1173825457942257
#
# Itteration: 34
# Current x: [-0.0000146  0.0367051  0.0239732]
# Current f(x): -0.017269567411058173
# Current grad: [-0.0001522 -0.091322   0.0528331]
# Step size: 0.04655306547292469
#
# Itteration: 35
# Current x: [-0.00002    0.0334515  0.0183495]
# Current f(x): -0.017449374207510526
# Current grad: [0.0000462 0.0277175 0.0479097]
# Step size: 0.11738254579422638
#
# Itteration: 36
# Current x: [-0.0000151  0.0364019  0.0166426]
# Current f(x): -0.017574157760200698
# Current grad: [-0.0001056 -0.0633763  0.0366655]
# Step size: 0.04655306547292464
#
# Itteration: 37
# Current x: [-0.0000189  0.034144   0.0127397]
# Current f(x): -0.017660755905149605
# Current grad: [0.0000321 0.0192356 0.0332487]
# Step size: 0.1173825457942273
#
# Itteration: 38
# Current x: [-0.0000154  0.0361915  0.0115552]
# Current f(x): -0.01772085387917678
# Current grad: [-0.0000733 -0.0439823  0.0254454]
# Step size: 0.04655306547292454
#
# Itteration: 39
# Current x: [-0.0000181  0.0346245  0.0088467]
# Current f(x): -0.017762561083000856
# Current grad: [0.0000222 0.0133492 0.0230742]
# Step size: 0.11738254579422774
#
# Itteration: 40
# Current x: [-0.0000157  0.0360454  0.0080246]
# Current f(x): -0.01779150533410051
# Current grad: [-0.0000509 -0.0305231  0.0176587]
# Step size: 0.046553065472924336
#
# Itteration: 41
# Current x: [-0.0000175  0.034958   0.0061449]
# Current f(x): -0.01781159226381302
# Current grad: [0.0000154 0.0092642 0.0160132]
# Step size: 0.11738254579422784
#
# Itteration: 42
# Current x: [-0.0000159  0.0359441  0.0055744]
# Current f(x): -0.017825532328936366
# Current grad: [-0.0000353 -0.0211826  0.0122549]
# Step size: 0.04655306547292447
#
# Itteration: 43
# Current x: [-0.0000171  0.0351894  0.00427  ]
# Current f(x): -0.01783520655085202
# Current grad: [0.0000107 0.0064292 0.0111129]
# Step size: 0.11738254579422595
#
# Itteration: 44
# Current x: [-0.000016   0.0358738  0.0038741]
# Current f(x): -0.017841920333667608
# Current grad: [-0.0000245 -0.0147005  0.0085048]
# Step size: 0.046553065472924544
#
# Itteration: 45
# Current x: [-0.0000168  0.03535    0.0029688]
# Current f(x): -0.017846579610670755
# Current grad: [0.0000074 0.0044618 0.0077122]
# Step size: 0.11738254579422595
#
# Itteration: 46
# Current x: [-0.000016  0.035825  0.002694]
# Current f(x): -0.01784981308765211
# Current grad: [-0.000017  -0.0102019  0.0059022]
# Step size: 0.04655306547292459
#
# Itteration: 47
# Current x: [-0.0000167  0.0354615  0.0020658]
# Current f(x): -0.017852057078164354
# Current grad: [0.0000052 0.0030964 0.0053522]
# Step size: 0.11738254579422769
#
# Itteration: 48
# Current x: [-0.0000161  0.0357911  0.0018751]
# Current f(x): -0.01785361437807651
# Current grad: [-0.0000118 -0.00708    0.004096 ]
# Step size: 0.046553065472924614
#
# Itteration: 49
# Current x: [-0.0000165  0.0355389  0.0014391]
# Current f(x): -0.01785469512374062
# Current grad: [0.0000036 0.0021489 0.0037143]
# Step size: 0.1173825457942197
#
# Itteration: 50
# Current x: [-0.0000161  0.0357676  0.0013067]
# Current f(x): -0.017855445147022184
# Current grad: [-0.0000082 -0.0049134  0.0028426]
# Step size: 0.04655306547292568
#
# Itteration: 51
# Current x: [-0.0000164  0.0355925  0.0010042]
# Current f(x): -0.01785596565331849
# Current grad: [0.0000025 0.0014913 0.0025777]
# Step size: 0.11738254579421921
#
# Itteration: 52
# Current x: [-0.0000162  0.0357513  0.0009123]
# Current f(x): -0.017856326877844667
# Current grad: [-0.0000057 -0.0034099  0.0019727]
# Step size: 0.04655306547292562
#
# Itteration: 53
# Current x: [-0.0000164  0.0356298  0.0007023]
# Current f(x): -0.017856577562916556
# Current grad: [0.0000017 0.0010349 0.0017889]
# Step size: 0.11738254579423088
#
# Itteration: 54
# Current x: [-0.0000162  0.03574    0.0006386]
# Current f(x): -0.01785675153506051
# Current grad: [-0.0000039 -0.0023664  0.001369 ]
# Step size: 0.046553065472925204
#
# Itteration: 55
# Current x: [-0.0000163  0.0356557  0.0004929]
# Current f(x): -0.017856872269441087
# Current grad: [0.0000012 0.0007182 0.0012415]
# Step size: 0.11738254579422365
#
# Itteration: 56
# Current x: [-0.0000162  0.0357321  0.0004486]
# Current f(x): -0.017856956057513817
# Current grad: [-0.0000027 -0.0016422  0.0009501]
# Step size: 0.046553065472925814
#
# Itteration: 57
# Current x: [-0.0000163  0.0356736  0.0003475]
# Current f(x): -0.017857014205334677
# Current grad: [0.0000008 0.0004984 0.0008616]
# Step size: 0.11738254579420745
#
# Itteration: 58
# Current x: [-0.0000162  0.0357267  0.0003168]
# Current f(x): -0.017857054559157835
# Current grad: [-0.0000019 -0.0011397  0.0006594]
# Step size: 0.04655306547292654
#
# Itteration: 59
# Current x: [-0.0000163  0.0356861  0.0002466]
# Current f(x): -0.017857082564180556
# Current grad: [0.0000006 0.0003459 0.0005979]
# Step size: 0.11738254579415543
#
# Itteration: 60
# Current x: [-0.0000162  0.0357229  0.0002253]
# Current f(x): -0.017857101999298113
# Current grad: [-0.0000013 -0.0007909  0.0004576]
# Step size: 0.04655306547293334
#
# Itteration: 61
# Current x: [-0.0000163  0.0356947  0.0001766]
# Current f(x): -0.01785711548701418
# Current grad: [0.0000004 0.0002401 0.0004149]
# Step size: 0.11738254579402264
#
# Itteration: 62
# Current x: [-0.0000162  0.0357202  0.0001618]
# Current f(x): -0.01785712484731179
# Current grad: [-0.0000009 -0.0005489  0.0003176]
# Step size: 0.046553065472944216
#
# Itteration: 63
# Current x: [-0.0000163  0.0357007  0.000128 ]
# Current f(x): -0.01785713134323527
# Current grad: [0.0000003 0.0001666 0.000288 ]
# Step size: 0.11738254579399623
#
# Itteration: 64
# Current x: [-0.0000162  0.0357184  0.0001178]
# Current f(x): -0.017857135851320753
# Current grad: [-0.0000006 -0.0003809  0.0002204]
# Step size: 0.046553065472957574
#
# Itteration: 65
# Current x: [-0.0000162  0.0357049  0.0000943]
# Current f(x): -0.017857138979872813
# Current grad: [0.0000002 0.0001156 0.0001998]
# Step size: 0.11738254579376525
#
# Itteration: 66
# Current x: [-0.0000162  0.0357172  0.0000872]
# Current f(x): -0.01785714115104681
# Current grad: [-0.0000004 -0.0002644  0.0001529]
# Step size: 0.04655306547299044
#
# Itteration: 67
# Current x: [-0.0000162  0.0357077  0.0000709]
# Current f(x): -0.017857142657813012
# Current grad: [0.0000001 0.0000802 0.0001387]
# Step size: 0.1173825457942239
#
# Itteration: 68
# Current x: [-0.0000162  0.0357163  0.000066 ]
# Current f(x): -0.017857143703488954
# Current grad: [-0.0000003 -0.0001835  0.0001061]
# Step size: 0.046553065472934516
#
# Converged in 68 itterations
