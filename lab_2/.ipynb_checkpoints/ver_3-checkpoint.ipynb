# %%
import numpy as np
np.set_printoptions(suppress=True,precision=7)

# %% [markdown]
# # Лабораторна робота №2

# %% [markdown]
# ## Цільова функція:

# %% [markdown]
# $$11x^2 + 14y^2 + z^2 + 0,01xy - 0,001yz - y$$

# %%
target_function = lambda x: 11*x[0]**2 + 14*x[1]**2 + x[2]**2 + 0.01*x[0]*x[1] - 0.001*x[1]*x[2] - x[1]

# %% [markdown]
# ## Умови зупинки:

# %% [markdown]
# $$||x^{k+1} - x^k||\leq\epsilon$$

# %%
def x_norm_stop(x_prev,x_cur,epselon):
    return np.linalg.norm(x_prev-x_cur) < epselon

# %% [markdown]
# $$||f(x^{k+1}) - f(x^k)||\leq\epsilon$$

# %%
def func_abs_stop(func_prev,func_cur,epselon):
    return abs(func_prev - func_cur) < epselon

# %% [markdown]
# $$||f'(x^{k+1})||\leq\epsilon$$

# %%
def grad_abs_stop(grad,epselon):
    return np.linalg.norm(grad)<epselon

# %% [markdown]
# ## Метод Ньютона

# %%
class NeutonMethod:
    
    def __init__(self, target_func, initial_x, grad_step_size, 
                 step_size=1,  adaptive_beta=0, adaptive_epselon=0, fastest_descent_eps=0):
        self.f = target_func
        self.x = initial_x
        
        self.f_value = self.f(self.x)
        
        self.grad_step_size = grad_step_size
        self.step_size = step_size
        self.adaptive_beta = adaptive_beta
        self.adaptive_epselon = adaptive_epselon
        self.initial_step_size = step_size
        self.fastest_descent_eps = fastest_descent_eps
        
        self.grad = None
        self.gesse_matrix = None
        
    @staticmethod
    def first_partial_deriv(f, x, h, var_num):
        x_back, x_forward = x.copy(), x.copy()
        
        # Increase x_back in such a way: (x-h;y)
        x_back[var_num] = x_back[var_num] - h 
        # Increase x_forward in such a way: (x+h;y)
        x_forward[var_num] = x_forward[var_num] + h
        
        return (f(x_forward) - f(x_back))/(2*h)
    
    @staticmethod
    def compose_grad_vec(f, x, h):
        # Compose vector from partial derivatives
        return np.array([NeutonMethod.first_partial_deriv(f,x,h,i) for i in range(x.shape[0])])
    
    @staticmethod
    def second_partial_deriv(f, x, h, var_1_num, var_2_num):
        x_back_back, x_back_for, x_for_back, x_for_for = x.copy(), x.copy(), x.copy(), x.copy()
        
        # Increase x_back_back in such a way: (x+h;y+h)
        x_back_back[var_1_num] = x_back_back[var_1_num] -h
        x_back_back[var_2_num] = x_back_back[var_2_num] -h
        
        # Increase x_back_for in such a way: (x-h;y+h)
        x_back_for[var_1_num] = x_back_for[var_1_num] -h
        x_back_for[var_2_num] = x_back_for[var_2_num] +h
        
        # Increase x_for_back in such a way: (x+h;y-h)
        x_for_back[var_1_num] = x_for_back[var_1_num] +h
        x_for_back[var_2_num] = x_for_back[var_2_num] -h
        
        # Increase x_for_for in such a way: (x-h;y-h)
        x_for_for[var_1_num] = x_for_for[var_1_num] +h
        x_for_for[var_2_num] = x_for_for[var_2_num] +h
        
        return (f(x_back_back) - f(x_back_for) - f(x_for_back) + f(x_for_for))/(4*h**2)
    
    @staticmethod
    def compose_gesse_matrix(f, x, h):
        gesse_matrix = np.zeros((x.shape[0],x.shape[0]))
        
        # Fill elements only under and in diagonal and copy elements upper diagonal (Gesse matrix is semetric)
        for i in range(gesse_matrix.shape[0]):
            for j in range(i+1):
                gesse_matrix[i,j] = NeutonMethod.second_partial_deriv(f,x,h,i,j)
                gesse_matrix[j,i] = gesse_matrix[i,j]
                
        return gesse_matrix
    
    '''
    @staticmethod
    def adaptive_step_size(f, current_f_value, alpha, beta):
        # decrease alpha_k until f(x_k) > f(x_k - alpha_k * inversed(f(x_k)'')f(x_k)')
        while current_f_value < f(alpha):
            alpha = alpha * beta
            
        return alpha
    '''
    
    @staticmethod
    def adaptive_step_size(f, current_f_value, grad, direction, alpha, beta, epselon):
        while f(alpha) - current_f_value > epselon*alpha*(grad@direction):
            alpha = alpha * beta
            
        return alpha

    
    @staticmethod
    def gold_section_search(f, a, b, eps):
        phi = 0.5 * (1.0 + 5.0**0.5)
        
        while abs(b-a) >= eps:
            x_1 = b - (b-a)/phi
            x_2 = a + (b-a)/phi
            
            if f(x_1) > f(x_2):
                a = x_1
            else:
                b = x_2
                
        return (a+b)/2
        
    def backward(self):
        self.grad = NeutonMethod.compose_grad_vec(self.f, self.x, self.grad_step_size) 
        self.gesse_matrix = NeutonMethod.compose_gesse_matrix(self.f, self.x, self.grad_step_size)
        
    def zero_grad(self):
        self.grad = np.zeros(self.x.shape[0])
        self.gesse_matrix = np.zeros((self.x.shape[0],self.x.shape[0]))
        
    def step(self):
        '''
        self.step_size = NeutonMethod.second_adaptive(f=lambda alpha: self.f(self.x - alpha * np.linalg.inv(self.gesse_matrix) @ self.grad),
                                                         current_f_value=self.f_value, grad=self.grad,
                                                         direction=-np.linalg.inv(self.gesse_matrix)@self.grad,
                                                         alpha=self.initial_step_size, beta=self.adaptive_beta,
                                                         epselon=0.25)
        
        '''
        # if beta > 0 and epselon > 0 we are using adaptive step_size
        if self.adaptive_beta > 0 and self.adaptive_epselon > 0:
            self.step_size = NeutonMethod.adaptive_step_size(f=lambda alpha: self.f(self.x - alpha * np.linalg.inv(self.gesse_matrix) @ self.grad),
                                                             current_f_value=self.f_value, grad=self.grad,
                                                             direction=-np.linalg.inv(self.gesse_matrix)@self.grad,
                                                             alpha=self.initial_step_size, beta=self.adaptive_beta,
                                                             epselon=self.adaptive_epselon)
        
        # if fastest descent epselon > 0 we are using fastest descent algorithm
        elif self.fastest_descent_eps > 0:
            self.step_size = NeutonMethod.gold_section_search(f=lambda alpha: self.f(self.x - alpha * np.linalg.inv(self.gesse_matrix) @ self.grad),
                                                              a=0, b=self.initial_step_size, 
                                                              eps=self.fastest_descent_eps)
        
        # x_k+1 = x_k - alpha_k * inversed(f(x_k)'')f(x_k)'
        self.x = self.x - self.step_size * np.linalg.inv(self.gesse_matrix) @ self.grad
        self.f_value = self.f(self.x)
        
    def info(self):
        print('Current x: {}'.format(self.x))
        print('Current f(x): {}'.format(self.f_value))
        print('Current grad: {}'.format(self.grad))
        print('Current gesse matrix:\n {}'.format(self.gesse_matrix))
        print('Step size: {}'.format(self.step_size))
        print('Gradient step size: {}'.format(self.grad_step_size))

# %% [markdown]
# Застосуємо метод з величиною кроку = 1

# %%
neuton_descent = NeutonMethod(target_func=target_function,
                              initial_x=np.array([10.,10.,10.]),
                              grad_step_size=0.00001)

# %%
eps = 0.001
num_itter = 0
previous_x = neuton_descent.x + eps + 1

while not x_norm_stop(neuton_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = neuton_descent.x
    neuton_descent.zero_grad()
    # Compute gradient and gesse matrix
    neuton_descent.backward()
    # x_k+1 = x_k + h_k
    neuton_descent.step()
    neuton_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [ 0.0003966  0.0353187 -0.0075965]
# Current f(x): -0.01779510688827444
# Current grad: [220.1       279.0899999  19.99     ]
# Current gesse matrix:
#  [[22.0006768  0.0102318  0.       ]
#  [ 0.0102318 27.9987944 -0.0011369]
#  [ 0.        -0.0011369  1.9986146]]
# Step size: 1
# Gradient step size: 1e-05
#
# Itteration: 2
# Current x: [-0.0000162  0.0357143  0.0000179]
# Current f(x): -0.017857146074907817
# Current grad: [ 0.0090781 -0.0110651 -0.0152283]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 1
# Gradient step size: 1e-05
#
# Itteration: 3
# Current x: [-0.0000162  0.0357143  0.0000179]
# Current f(x): -0.017857146074907817
# Current grad: [-0. -0. -0.]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 1
# Gradient step size: 1e-05
#
# Converged in 3 itterations

# %% [markdown]
# Застосуємо метод з постійною величиною кроку

# %%
neuton_descent = NeutonMethod(target_func=target_function,
                              initial_x=np.array([10.,10.,10.]),
                              grad_step_size=0.00001,
                              step_size=0.1)

# %%
eps = 0.00001
num_itter = 0
previous_x = neuton_descent.x + eps + 1

while not x_norm_stop(neuton_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = neuton_descent.x
    neuton_descent.zero_grad()
    # Compute gradient and gesse matrix
    neuton_descent.backward()
    # x_k+1 = x_k + h_k
    neuton_descent.step()
    neuton_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [9.0000397 9.0035319 8.9992404]
# Current f(x): 2098.610149608585
# Current grad: [220.1       279.0899999  19.99     ]
# Current gesse matrix:
#  [[22.0006768  0.0102318  0.       ]
#  [ 0.0102318 27.9987944 -0.0011369]
#  [ 0.        -0.0011369  1.9986146]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 2
# Current x: [8.0999318 8.106751  8.099143 ]
# Current f(x): 1699.8499670335518
# Current grad: [198.0909078 251.1798935  17.9894772]
# Current gesse matrix:
#  [[21.9984031  0.0090949  0.       ]
#  [ 0.0090949 27.9999313  0.       ]
#  [ 0.         0.         1.9986146]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 3
# Current x: [7.2899704 7.2996317 7.2886148]
# Current f(x): 1376.8682733708
# Current grad: [178.279568  226.0619279  16.1901792]
# Current gesse matrix:
#  [[22.0001084  0.0108002  0.       ]
#  [ 0.0108002 27.9993628 -0.0017053]
#  [ 0.        -0.0017053  1.999183 ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 4
# Current x: [6.5609265 6.5732259 6.5602353]
# Current f(x): 1115.257110822089
# Current grad: [160.4523449 203.4552974  14.5699299]
# Current gesse matrix:
#  [[21.9989715  0.0096634  0.       ]
#  [ 0.0096634 27.9993628 -0.0005684]
#  [ 0.        -0.0005684  2.0008883]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 5
# Current x: [5.9048424 5.9194753 5.9040873]
# Current f(x): 903.3547927479422
# Current grad: [144.4061161 183.1093737  13.1138974]
# Current gesse matrix:
#  [[22.0001084  0.0102318  0.       ]
#  [ 0.0102318 27.9999313 -0.0011369]
#  [ 0.        -0.0011369  1.9997515]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 6
# Current x: [5.314358  5.3310819 5.3137345]
# Current f(x): 731.7121641993044
# Current grad: [129.9657272 164.7984537  11.8022552]
# Current gesse matrix:
#  [[22.0001084  0.0099476  0.       ]
#  [ 0.0099476 27.9993628 -0.0011369]
#  [ 0.        -0.0011369  2.0003199]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 7
# Current x: [4.7829219 4.8015402 4.7823361]
# Current f(x): 592.6826942341658
# Current grad: [116.9691876 148.3181217  10.622138 ]
# Current gesse matrix:
#  [[21.9998242  0.0102318  0.       ]
#  [ 0.0102318 27.999647  -0.0011369]
#  [ 0.        -0.0011369  2.0000357]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 8
# Current x: [4.3046417 4.3249629 4.3040802]
# Current f(x): 480.07130136998217
# Current grad: [105.2722982 133.4861731   9.5598707]
# Current gesse matrix:
#  [[22.0003926  0.0102318  0.       ]
#  [ 0.0102318 28.0002155 -0.0011369]
#  [ 0.        -0.0011369  2.0000357]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 9
# Current x: [3.8741742 3.8960363 3.8736522]
# Current f(x): 388.85385705505803
# Current grad: [ 94.7453666 120.1377039   8.6038354]
# Current gesse matrix:
#  [[21.9999663  0.0099476  0.       ]
#  [ 0.0099476 27.9999313 -0.0009948]
#  [ 0.        -0.0009948  1.9998936]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 10
# Current x: [3.4867586 3.5100084 3.4862692]
# Current f(x): 314.96877866345284
# Current grad: [ 85.270793  108.1238837   7.7434083]
# Current gesse matrix:
#  [[22.0001084  0.0100897  0.       ]
#  [ 0.0100897 28.0002155 -0.0009948]
#  [ 0.        -0.0009948  1.9998936]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 11
# Current x: [3.1380821 3.1625757 3.1376264]
# Current f(x): 255.1209881641548
# Current grad: [76.7437903 97.3116153  6.9690283]
# Current gesse matrix:
#  [[22.0001084  0.0099476  0.       ]
#  [ 0.0099476 27.9997892 -0.0009948]
#  [ 0.        -0.0009948  1.9998936]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 12
# Current x: [2.824273  2.8498939 2.8238942]
# Current f(x): 206.64515502960126
# Current grad: [69.0694309 87.5803641  6.2720902]
# Current gesse matrix:
#  [[21.9999663  0.0100897  0.       ]
#  [ 0.0100897 28.0001444 -0.0008527]
#  [ 0.        -0.0008527  2.0000357]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 13
# Current x: [2.5418439 2.5684748 2.5415023]
# Current f(x): 167.37906768013113
# Current grad: [62.1625052 78.8224472  5.6449384]
# Current gesse matrix:
#  [[21.9998952  0.0100897  0.       ]
#  [ 0.0100897 27.9997892 -0.0009948]
#  [ 0.        -0.0009948  1.9999646]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 14
# Current x: [2.2876569 2.315197  2.28735  ]
# Current f(x): 135.57347644502727
# Current grad: [55.9462504 70.94017    5.0804361]
# Current gesse matrix:
#  [[21.9999663  0.0099476  0.       ]
#  [ 0.0099476 27.9999313 -0.0010658]
#  [ 0.        -0.0010658  2.0000357]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 15
# Current x: [2.0588894 2.0872495 2.0586215]
# Current f(x): 109.81118073068448
# Current grad: [50.3516035 63.8461055  4.5723849]
# Current gesse matrix:
#  [[21.9999663  0.0100187  0.       ]
#  [ 0.0100187 28.0000734 -0.0009948]
#  [ 0.        -0.0009948  2.0000357]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 16
# Current x: [1.8529987 1.8820965 1.852758 ]
# Current f(x): 88.94366968706308
# Current grad: [45.3164397 57.4615172  4.1151558]
# Current gesse matrix:
#  [[22.0000018  0.0099831  0.       ]
#  [ 0.0099831 28.0000734 -0.0009948]
#  [ 0.        -0.0009948  1.9999646]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 17
# Current x: [1.6676971 1.6974579 1.6674779]
# Current f(x): 72.04094089550613
# Current grad: [40.7847926 51.7153781  3.703634 ]
# Current gesse matrix:
#  [[21.9999663  0.0100187  0.       ]
#  [ 0.0100187 27.9999668 -0.0010303]
#  [ 0.        -0.0010303  1.9999646]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 18
# Current x: [1.5009259 1.5312833 1.5007324]
# Current f(x): 58.349764599625075
# Current grad: [36.7063106 46.543832   3.3332584]
# Current gesse matrix:
#  [[22.0000018  0.0100187  0.       ]
#  [ 0.0100187 27.9999313 -0.0009948]
#  [ 0.        -0.0009948  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 19
# Current x: [1.3508318 1.3817264 1.35066  ]
# Current f(x): 47.25991623828758
# Current grad: [33.0356829 41.8894414  2.9999335]
# Current gesse matrix:
#  [[22.0000196  0.0100009  0.       ]
#  [ 0.0100009 28.0000023 -0.0010125]
#  [ 0.        -0.0010125  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 20
# Current x: [1.2157469 1.2471252 1.215595 ]
# Current f(x): 38.27713617107669
# Current grad: [29.7321177 37.7004958  2.6999383]
# Current gesse matrix:
#  [[22.0000018  0.0099831  0.       ]
#  [ 0.0099831 28.0000201 -0.0009948]
#  [ 0.        -0.0009948  1.9999824]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 21
# Current x: [1.0941707 1.1259841 1.0940365]
# Current f(x): 31.001089636291944
# Current grad: [26.7589039 33.9304474  2.4299428]
# Current gesse matrix:
#  [[22.0000018  0.0100187  0.       ]
#  [ 0.0100187 28.0000023 -0.0010125]
#  [ 0.        -0.0010125  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 22
# Current x: [0.9847521 1.0169571 0.9846349]
# Current f(x): 25.107489625055578
# Current grad: [24.083016  30.5374037  2.186947 ]
# Current gesse matrix:
#  [[22.0000196  0.0099831  0.       ]
#  [ 0.0099831 28.0000023 -0.0009948]
#  [ 0.        -0.0009948  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 23
# Current x: [0.8862752 0.9188329 0.8861735]
# Current f(x): 20.33367517851553
# Current grad: [21.6747147 27.4836623  1.9682529]
# Current gesse matrix:
#  [[22.0000018  0.0100009  0.       ]
#  [ 0.0100009 28.0000023 -0.0009948]
#  [ 0.        -0.0009948  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 24
# Current x: [0.797646  0.8305209 0.7975582]
# Current f(x): 16.46688019795071
# Current grad: [19.5072435 24.7352969  1.7714281]
# Current gesse matrix:
#  [[21.9999841  0.0099831  0.       ]
#  [ 0.0099831 27.9999846 -0.0009948]
#  [ 0.        -0.0009948  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 25
# Current x: [0.7178797 0.7510402 0.7178047]
# Current f(x): 13.334780545890984
# Current grad: [17.5565162 22.2617648  1.5942858]
# Current gesse matrix:
#  [[21.9999929  0.0100098  0.       ]
#  [ 0.0100098 27.9999846 -0.0010036]
#  [ 0.        -0.0010036  2.0000179]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 26
# Current x: [0.6460901 0.6795076 0.6460259]
# Current f(x): 10.797778507836652
# Current grad: [15.8008648 20.0355876  1.4348584]
# Current gesse matrix:
#  [[21.9999974  0.0099964  0.       ]
#  [ 0.0099964 27.9999934 -0.0009992]
#  [ 0.        -0.0009992  1.9999957]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 27
# Current x: [0.5814795 0.6151283 0.5814248]
# Current f(x): 8.742807354932413
# Current grad: [14.2207779 18.0320282  1.2913723]
# Current gesse matrix:
#  [[22.0000018  0.0099964  0.       ]
#  [ 0.0099964 28.0000068 -0.0010036]
#  [ 0.        -0.0010036  1.9999957]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 28
# Current x: [0.5233299 0.5571869 0.5232842]
# Current f(x): 7.078281602843822
# Current grad: [12.7987    16.2288253  1.1622345]
# Current gesse matrix:
#  [[22.0000063  0.0100053  0.       ]
#  [ 0.0100053 27.9999979 -0.0009992]
#  [ 0.        -0.0009992  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 29
# Current x: [0.4709953 0.5050396 0.4709575]
# Current f(x): 5.730015102311627
# Current grad: [11.5188307 14.605943   1.0460111]
# Current gesse matrix:
#  [[21.9999996  0.0100009  0.       ]
#  [ 0.0100009 27.9999957 -0.0010014]
#  [ 0.        -0.0010014  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 30
# Current x: [0.4238942 0.4581071 0.4238635]
# Current f(x): 4.637919218185855
# Current grad: [10.3669476 13.1453485  0.94141  ]
# Current gesse matrix:
#  [[21.9999952  0.0100009  0.       ]
#  [ 0.0100009 28.0000001 -0.0010014]
#  [ 0.        -0.0010014  1.9999979]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 31
# Current x: [0.3815031 0.4158678 0.3814788]
# Current f(x): 3.7533216893468397
# Current grad: [ 9.3302527 11.8308136  0.8472688]
# Current gesse matrix:
#  [[22.000004   0.0100009 -0.0000022]
#  [ 0.0100009 28.0000045 -0.0010036]
#  [-0.0000022 -0.0010036  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 32
# Current x: [0.3433512 0.3778525 0.3433327]
# Current f(x): 3.03679779619554
# Current grad: [ 8.3972275 10.6477323  0.7625417]
# Current gesse matrix:
#  [[21.9999996  0.0100031  0.       ]
#  [ 0.0100031 28.0000034 -0.0010014]
#  [ 0.        -0.0010014  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 33
# Current x: [0.3090144 0.3436386 0.3090012]
# Current f(x): 2.4564133092533385
# Current grad: [7.5575049 9.5829593 0.6862875]
# Current gesse matrix:
#  [[21.9999985  0.0099976  0.       ]
#  [ 0.0099976 27.999999  -0.0009992]
#  [ 0.        -0.0009992  2.0000013]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 34
# Current x: [0.2781114 0.3128462 0.2781029]
# Current f(x): 1.986301931517179
# Current grad: [6.8017543 8.6246633 0.6176588]
# Current gesse matrix:
#  [[22.0000018  0.0100009  0.       ]
#  [ 0.0100009 27.9999979 -0.0009992]
#  [ 0.        -0.0009992  1.9999979]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 35
# Current x: [0.2502986 0.285133  0.2502944]
# Current f(x): 1.6055117253345905
# Current grad: [6.1215789 7.7621969 0.5558929]
# Current gesse matrix:
#  [[21.9999985  0.0100009  0.       ]
#  [ 0.0100009 28.0000007 -0.0009992]
#  [ 0.        -0.0009992  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 36
# Current x: [0.2252671 0.2601911 0.2252667]
# Current f(x): 1.2970716517171548
# Current grad: [5.509421  6.9859773 0.5003036]
# Current gesse matrix:
#  [[22.0000007  0.0100003  0.       ]
#  [ 0.0100003 28.0000012 -0.0010003]
#  [ 0.        -0.0010003  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 37
# Current x: [0.2027388 0.2377435 0.2027418]
# Current f(x): 1.0472351898153838
# Current grad: [4.9584789 6.2873796 0.4502732]
# Current gesse matrix:
#  [[21.9999996  0.0100003  0.       ]
#  [ 0.0100003 28.0000001 -0.0009992]
#  [ 0.        -0.0009992  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 38
# Current x: [0.1824633 0.2175405 0.1824694]
# Current f(x): 0.8448676354268361
# Current grad: [4.462631  5.6586417 0.4052459]
# Current gesse matrix:
#  [[22.0000002  0.0099998  0.       ]
#  [ 0.0099998 27.999999  -0.0010003]
#  [ 0.        -0.0010003  1.9999991]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 39
# Current x: [0.1642153 0.1993579 0.1642243]
# Current f(x): 0.6809499349548159
# Current grad: [4.0163679 5.0927775 0.3647213]
# Current gesse matrix:
#  [[22.0000002  0.0100003  0.       ]
#  [ 0.0100003 28.0000007 -0.0009998]
#  [ 0.        -0.0009998  2.0000007]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 40
# Current x: [0.1477922 0.1829936 0.1478036]
# Current f(x): 0.5481765913585923
# Current grad: [3.6147311 4.5834997 0.3282492]
# Current gesse matrix:
#  [[22.0000004  0.0100003  0.       ]
#  [ 0.0100003 27.9999998 -0.0010003]
#  [ 0.        -0.0010003  2.0000004]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 41
# Current x: [0.1330113 0.1682656 0.1330251]
# Current f(x): 0.44063017997904796
# Current grad: [3.253258  4.1251498 0.2954243]
# Current gesse matrix:
#  [[22.0000002  0.0099998  0.       ]
#  [ 0.0099998 28.0000001 -0.0010003]
#  [ 0.        -0.0010003  2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 42
# Current x: [0.1197086 0.1550105 0.1197243]
# Current f(x): 0.3535175869961267
# Current grad: [2.9279322 3.7126348 0.2658819]
# Current gesse matrix:
#  [[21.9999993  0.0100003  0.       ]
#  [ 0.0100003 27.9999998 -0.001    ]
#  [ 0.        -0.001      1.9999996]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 43
# Current x: [0.1077361 0.1430809 0.1077537]
# Current f(x): 0.28295638652337785
# Current grad: [2.635139  3.3413713 0.2392937]
# Current gesse matrix:
#  [[21.9999999  0.0100001  0.       ]
#  [ 0.0100001 27.9999998 -0.0010003]
#  [ 0.        -0.0010003  1.9999999]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 44
# Current x: [0.0969609 0.1323442 0.0969801]
# Current f(x): 0.22580181465830318
# Current grad: [2.3716251 3.0072342 0.2153643]
# Current gesse matrix:
#  [[21.9999999  0.0099998  0.0000003]
#  [ 0.0099998 27.9999995 -0.001    ]
#  [ 0.0000003 -0.001      1.9999999]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 45
# Current x: [0.0872632 0.1226812 0.0872839]
# Current f(x): 0.17950661192337924
# Current grad: [2.1344626 2.7065107 0.1938279]
# Current gesse matrix:
#  [[21.9999999  0.0100001  0.       ]
#  [ 0.0100001 27.9999998 -0.0009999]
#  [ 0.        -0.0009999  1.9999997]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 46
# Current x: [0.0785352 0.1139845 0.0785573]
# Current f(x): 0.14200749784038968
# Current grad: [1.9210163 2.4358597 0.1744451]
# Current gesse matrix:
#  [[22.         0.0099999  0.       ]
#  [ 0.0099999 28.        -0.0009999]
#  [ 0.        -0.0009999  1.9999999]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 47
# Current x: [0.0706801 0.1061575 0.0707033]
# Current f(x): 0.11163321559933333
# Current grad: [1.7289147 2.1922737 0.1570006]
# Current gesse matrix:
#  [[22.0000002  0.0100001  0.       ]
#  [ 0.0100001 28.        -0.001    ]
#  [ 0.        -0.001      2.       ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 48
# Current x: [0.0636104 0.0991132 0.0636348]
# Current f(x): 0.08703004687089227
# Current grad: [1.5560232 1.9730463 0.1413005]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 49
# Current x: [0.0572478 0.0927733 0.0572731]
# Current f(x): 0.06710148007695578
# Current grad: [1.4004209 1.7757417 0.1271705]
# Current gesse matrix:
#  [[21.9999999  0.01       0.       ]
#  [ 0.01      27.9999998 -0.001    ]
#  [ 0.        -0.001      2.       ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 50
# Current x: [0.0515214 0.0870674 0.0515476]
# Current f(x): 0.050959341203439354
# Current grad: [1.2603788 1.5981675 0.1144534]
# Current gesse matrix:
#  [[22.0000001  0.0100001  0.       ]
#  [ 0.0100001 28.        -0.001    ]
#  [ 0.        -0.001      2.       ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 51
# Current x: [0.0463676 0.0819321 0.0463946]
# Current f(x): 0.03788420863163776
# Current grad: [1.1343409 1.4383508 0.1030081]
# Current gesse matrix:
#  [[21.9999999  0.01       0.       ]
#  [ 0.01      28.        -0.001    ]
#  [ 0.        -0.001      2.0000002]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 52
# Current x: [0.0417292 0.0773103 0.0417569]
# Current f(x): 0.027293351239663824
# Current grad: [1.0209068 1.2945157 0.0927073]
# Current gesse matrix:
#  [[22.         0.01       0.       ]
#  [ 0.01      27.9999999 -0.001    ]
#  [ 0.        -0.001      2.       ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 53
# Current x: [0.0375547 0.0731507 0.037583 ]
# Current f(x): 0.018714756757101644
# Current grad: [0.9188162 1.1650641 0.0834365]
# Current gesse matrix:
#  [[22.         0.01       0.       ]
#  [ 0.01      28.0000001 -0.001    ]
#  [ 0.        -0.001      2.       ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 54
# Current x: [0.0337976 0.0694071 0.0338265]
# Current f(x): 0.011766095238078117
# Current grad: [0.8269345 1.0485577 0.0750929]
# Current gesse matrix:
#  [[22.         0.0100001  0.       ]
#  [ 0.0100001 28.        -0.001    ]
#  [ 0.        -0.001      2.0000001]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 55
# Current x: [0.0304162 0.0660378 0.0304456]
# Current f(x): 0.006137679386276573
# Current grad: [0.7442411 0.9437019 0.0675836]
# Current gesse matrix:
#  [[22.         0.01       0.       ]
#  [ 0.01      27.9999999 -0.001    ]
#  [ 0.        -0.001      2.       ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 56
# Current x: [0.027373  0.0630054 0.0274029]
# Current f(x): 0.0015786625467408416
# Current grad: [0.669817  0.8493317 0.0608252]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 57
# Current x: [0.024634  0.0602763 0.0246644]
# Current f(x): -0.0021141410812625244
# Current grad: [0.6028353 0.7643986 0.0547427]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 58
# Current x: [0.022169  0.0578201 0.0221997]
# Current f(x): -0.005105312031310955
# Current grad: [0.5425518 0.6879587 0.0492684]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 59
# Current x: [0.0199505 0.0556095 0.0199815]
# Current f(x): -0.00752816050290718
# Current grad: [0.4882966 0.6191628 0.0443416]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 60
# Current x: [0.0179538 0.05362   0.0179852]
# Current f(x): -0.009490667761170968
# Current grad: [0.4394669 0.5572466 0.0399074]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 61
# Current x: [0.0161568 0.0518294 0.0161884]
# Current f(x): -0.011080298638936108
# Current grad: [0.3955202 0.5015219 0.0359167]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 62
# Current x: [0.0145395 0.0502179 0.0145714]
# Current f(x): -0.01236789965068711
# Current grad: [0.3559682 0.4513697 0.032325 ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 63
# Current x: [0.0130839 0.0487676 0.013116 ]
# Current f(x): -0.013410856471726837
# Current grad: [0.3203714 0.4062327 0.0290925]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 64
# Current x: [0.0117739 0.0474622 0.0118062]
# Current f(x): -0.014255651496953244
# Current grad: [0.2883342 0.3656095 0.0261833]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 65
# Current x: [0.0105949 0.0462874 0.0106274]
# Current f(x): -0.014939935466402154
# Current grad: [0.2595008 0.3290485 0.0235649]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 66
# Current x: [0.0095338 0.0452301 0.0095664]
# Current f(x): -0.015494205482599357
# Current grad: [0.2335507 0.2961437 0.0212084]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 67
# Current x: [0.0085788 0.0442785 0.0086116]
# Current f(x): -0.015943164194901313
# Current grad: [0.2101957 0.2665293 0.0190876]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 68
# Current x: [0.0077193 0.0434221 0.0077522]
# Current f(x): -0.016306820752255674
# Current grad: [0.1891761 0.2398764 0.0171788]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 69
# Current x: [0.0069457 0.0426513 0.0069788]
# Current f(x): -0.016601382563637194
# Current grad: [0.1702585 0.2158887 0.015461 ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 70
# Current x: [0.0062495 0.0419576 0.0062827]
# Current f(x): -0.016839977630841493
# Current grad: [0.1532326 0.1942999 0.0139149]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 71
# Current x: [0.005623  0.0413333 0.0056562]
# Current f(x): -0.017033239635356152
# Current grad: [0.1379094 0.1748699 0.0125234]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 72
# Current x: [0.005059  0.0407714 0.0050924]
# Current f(x): -0.01718978185883799
# Current grad: [0.1241184 0.1573829 0.011271 ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 73
# Current x: [0.0045515 0.0402657 0.0045849]
# Current f(x): -0.017316581059884234
# Current grad: [0.1117066 0.1416446 0.0101439]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 74
# Current x: [0.0040947 0.0398105 0.0041282]
# Current f(x): -0.01741928841274929
# Current grad: [0.1005359 0.1274801 0.0091295]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 75
# Current x: [0.0036836 0.0394009 0.0037172]
# Current f(x): -0.01750248136852893
# Current grad: [0.0904823 0.1147321 0.0082166]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 76
# Current x: [0.0033137 0.0390323 0.0033472]
# Current f(x): -0.0175698676627161
# Current grad: [0.0814341 0.1032589 0.0073949]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 77
# Current x: [0.0029807 0.0387005 0.0030143]
# Current f(x): -0.017624450561020945
# Current grad: [0.0732907 0.092933  0.0066554]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 78
# Current x: [0.002681  0.0384018 0.0027147]
# Current f(x): -0.017668662708622086
# Current grad: [0.0659616 0.0836397 0.0059899]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 79
# Current x: [0.0024113 0.0381331 0.002445 ]
# Current f(x): -0.017704474548203123
# Current grad: [0.0593655 0.0752757 0.0053909]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 80
# Current x: [0.0021685 0.0378912 0.0022023]
# Current f(x): -0.017733482138284594
# Current grad: [0.0534289 0.0677482 0.0048518]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 81
# Current x: [0.00195   0.0376735 0.0019838]
# Current f(x): -0.01775697828622692
# Current grad: [0.048086  0.0609734 0.0043666]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 82
# Current x: [0.0017534 0.0374776 0.0017872]
# Current f(x): -0.017776010166084273
# Current grad: [0.0432774 0.054876  0.00393  ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 83
# Current x: [0.0015764 0.0373013 0.0016103]
# Current f(x): -0.017791425988755057
# Current grad: [0.0389497 0.0493884 0.003537 ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 84
# Current x: [0.0014172 0.0371426 0.001451 ]
# Current f(x): -0.017803912805129354
# Current grad: [0.0350547 0.0444496 0.0031833]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 85
# Current x: [0.0012738 0.0369997 0.0013077]
# Current f(x): -0.017814027126386654
# Current grad: [0.0315492 0.0400046 0.0028649]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 86
# Current x: [0.0011448 0.0368712 0.0011787]
# Current f(x): -0.017822219726607837
# Current grad: [0.0283943 0.0360042 0.0025785]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 87
# Current x: [0.0010287 0.0367555 0.0010627]
# Current f(x): -0.01782885573278551
# Current grad: [0.0255549 0.0324037 0.0023206]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 88
# Current x: [0.0009242 0.0366514 0.0009582]
# Current f(x): -0.017834230897792725
# Current grad: [0.0229994 0.0291634 0.0020885]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 89
# Current x: [0.0008302 0.0365577 0.0008641]
# Current f(x): -0.017838584781443647
# Current grad: [0.0206995 0.026247  0.0018797]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 90
# Current x: [0.0007455 0.0364733 0.0007795]
# Current f(x): -0.017842111427202746
# Current grad: [0.0186295 0.0236223 0.0016917]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 91
# Current x: [0.0006694 0.0363974 0.0007033]
# Current f(x): -0.017844968010264764
# Current grad: [0.0167666 0.0212601 0.0015226]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 92
# Current x: [0.0006008 0.0363291 0.0006348]
# Current f(x): -0.017847281842546442
# Current grad: [0.0150899 0.0191341 0.0013703]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 93
# Current x: [0.0005391 0.0362676 0.0005731]
# Current f(x): -0.017849156046695007
# Current grad: [0.0135809 0.0172207 0.0012333]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 94
# Current x: [0.0004836 0.0362123 0.0005176]
# Current f(x): -0.017850674152055362
# Current grad: [0.0122228 0.0154986 0.0011099]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 95
# Current x: [0.0004336 0.0361625 0.0004676]
# Current f(x): -0.01785190381739686
# Current grad: [0.0110005 0.0139487 0.0009989]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 96
# Current x: [0.0003886 0.0361177 0.0004226]
# Current f(x): -0.017852899846324197
# Current grad: [0.0099005 0.0125539 0.0008991]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 97
# Current x: [0.0003481 0.0360773 0.0003822]
# Current f(x): -0.017853706629755172
# Current grad: [0.0089104 0.0112985 0.0008091]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 98
# Current x: [0.0003117 0.036041  0.0003457]
# Current f(x): -0.017854360124334456
# Current grad: [0.0080194 0.0101686 0.0007282]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 99
# Current x: [0.0002789 0.0360084 0.0003129]
# Current f(x): -0.017854889454943033
# Current grad: [0.0072175 0.0091518 0.0006554]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 100
# Current x: [0.0002494 0.035979  0.0002834]
# Current f(x): -0.01785531821273638
# Current grad: [0.0064957 0.0082366 0.0005899]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 101
# Current x: [0.0002228 0.0359525 0.0002569]
# Current f(x): -0.01785566550654899
# Current grad: [0.0058461 0.0074129 0.0005309]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 102
# Current x: [0.0001989 0.0359287 0.000233 ]
# Current f(x): -0.01785594681453728
# Current grad: [0.0052615 0.0066716 0.0004778]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 103
# Current x: [0.0001774 0.0359072 0.0002115]
# Current f(x): -0.01785617467400781
# Current grad: [0.0047354 0.0060045 0.00043  ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 104
# Current x: [0.000158  0.0358879 0.0001921]
# Current f(x): -0.017856359240178834
# Current grad: [0.0042618 0.005404  0.000387 ]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 105
# Current x: [0.0001406 0.0358706 0.0001747]
# Current f(x): -0.01785650873877728
# Current grad: [0.0038357 0.0048636 0.0003483]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 106
# Current x: [0.0001249 0.0358549 0.000159 ]
# Current f(x): -0.017856629832642034
# Current grad: [0.0034521 0.0043773 0.0003135]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 107
# Current x: [0.0001108 0.0358409 0.0001449]
# Current f(x): -0.017856727918672547
# Current grad: [0.0031069 0.0039395 0.0002821]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 108
# Current x: [0.0000981 0.0358282 0.0001322]
# Current f(x): -0.017856807368357253
# Current grad: [0.0027962 0.0035456 0.0002539]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 109
# Current x: [0.0000867 0.0358168 0.0001207]
# Current f(x): -0.01785687172260185
# Current grad: [0.0025166 0.003191  0.0002285]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 110
# Current x: [0.0000764 0.0358066 0.0001105]
# Current f(x): -0.017856923849539963
# Current grad: [0.0022649 0.0028719 0.0002057]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 111
# Current x: [0.0000671 0.0357973 0.0001012]
# Current f(x): -0.017856966072359853
# Current grad: [0.0020384 0.0025847 0.0001851]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 112
# Current x: [0.0000588 0.035789  0.0000929]
# Current f(x): -0.01785700027284398
# Current grad: [0.0018346 0.0023263 0.0001666]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 113
# Current x: [0.0000513 0.0357816 0.0000854]
# Current f(x): -0.017857027975236105
# Current grad: [0.0016511 0.0020936 0.0001499]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 114
# Current x: [0.0000445 0.0357748 0.0000786]
# Current f(x): -0.017857050414173726
# Current grad: [0.001486  0.0018843 0.0001349]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 115
# Current x: [0.0000385 0.0357688 0.0000725]
# Current f(x): -0.017857068589713202
# Current grad: [0.0013374 0.0016958 0.0001214]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Itteration: 116
# Current x: [0.000033  0.0357633 0.0000671]
# Current f(x): -0.017857083311900192
# Current grad: [0.0012037 0.0015263 0.0001093]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.1
# Gradient step size: 1e-05
#
# Converged in 116 itterations

# %% [markdown]
# Застосуємо метод з адаптивною величиною кроку

# %%
neuton_descent = NeutonMethod(target_func=target_function,
                              initial_x=np.array([10.,10.,10.]),
                              grad_step_size=0.00001,
                              step_size=1,
                              adaptive_beta=0.5,
                              adaptive_epselon=0.25)

# %%
eps = 0.001
num_itter = 0
previous_x = neuton_descent.x + eps + 1

while not x_norm_stop(neuton_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = neuton_descent.x
    neuton_descent.zero_grad()
    # Compute gradient and gesse matrix
    neuton_descent.backward()
    # x_k+1 = x_k + h_k
    neuton_descent.step()
    neuton_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [ 0.0003966  0.0353187 -0.0075965]
# Current f(x): -0.01779510688827444
# Current grad: [220.1       279.0899999  19.99     ]
# Current gesse matrix:
#  [[22.0006768  0.0102318  0.       ]
#  [ 0.0102318 27.9987944 -0.0011369]
#  [ 0.        -0.0011369  1.9986146]]
# Step size: 1
# Gradient step size: 1e-05
#
# Itteration: 2
# Current x: [-0.0000162  0.0357143  0.0000179]
# Current f(x): -0.017857146074907817
# Current grad: [ 0.0090781 -0.0110651 -0.0152283]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 1
# Gradient step size: 1e-05
#
# Itteration: 3
# Current x: [-0.0000162  0.0357143  0.0000179]
# Current f(x): -0.01785714607490782
# Current grad: [-0. -0. -0.]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.5
# Gradient step size: 1e-05
#
# Converged in 3 itterations

# %% [markdown]
# Застосуємо метод найшвидшого спупску

# %%
neuton_descent = NeutonMethod(target_func=target_function,
                              initial_x=np.array([1.,1.,1.]),
                              step_size=1,
                              grad_step_size=0.00001,
                              fastest_descent_eps=0.00001)

# %%
eps = 0.001
num_itter = 0
previous_x = neuton_descent.x + eps + 1

while not x_norm_stop(neuton_descent.x,previous_x,eps):
    num_itter +=1
    print('\nItteration: {}'.format(num_itter))
    
    previous_x = neuton_descent.x
    neuton_descent.zero_grad()
    # Compute gradient and gesse matrix
    neuton_descent.backward()
    # x_k+1 = x_k + h_k
    neuton_descent.step()
    neuton_descent.info()
    
print('\nConverged in {} itterations'.format(num_itter))
# Out:
# Itteration: 1
# Current x: [-0.0000109  0.0357202  0.000034 ]
# Current f(x): -0.01785714501544074
# Current grad: [22.01  27.009  1.999]
# Current gesse matrix:
#  [[22.0000107  0.0100009  0.       ]
#  [ 0.0100009 28.0000201 -0.0009859]
#  [ 0.        -0.0009859  2.000009 ]]
# Step size: 0.9999951775621607
# Gradient step size: 1e-05
#
# Itteration: 2
# Current x: [-0.0000162  0.0357143  0.0000179]
# Current f(x): -0.01785714607490781
# Current grad: [0.0001177 0.0001646 0.0000323]
# Current gesse matrix:
#  [[22.     0.01   0.   ]
#  [ 0.01  28.    -0.001]
#  [ 0.    -0.001  2.   ]]
# Step size: 0.9999602820741389
# Gradient step size: 1e-05
#
# Converged in 2 itterations
